# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
import unidecode

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_current_members_of_the_United_States_House_of_Representatives'
response = requests.get(wiki_url)
soup = BeautifulSoup(response.text,"lxml")

house_of_reps_text = soup.find('table',attrs={'class':"wikitable sortable plainrowheaders", 'id': "votingmembers"})

# %%
representatives = pd.read_html(str(house_of_reps_text))[0]
representatives = representatives.drop(['Party'], axis=1)
representatives = representatives.rename(columns={'Party.1': 'Party', 'Born[4]': 'Age'})

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_current_United_States_senators?fbclid=IwAR3fwBqo12plcIm741lp9eP2ALJ4G49Ntch2P9_Dxg8cOmiQKODTrPluMT8'
response = requests.get(wiki_url)
soup = BeautifulSoup(response.text,"lxml")

senators_text = soup.find('table',attrs={'class':"wikitable sortable", 'id': "senators"})
senators = pd.read_html(str(senators_text))[0]
senators = senators.drop(['Party', 'Portrait'], axis=1)
senators = senators.rename(columns={'Party.1': 'Party', 'Residence[5]': 'Residence', 'Born': 'Age'})
# save to csv

# %%
# Save to csv 
representatives.to_csv('usa_data/house.csv', index=False)
senators.to_csv('usa_data/senators.csv', index=False)

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('usa_data/house.csv')
df1 = pd.read_csv('usa_data/senators.csv')

# Define a function to clean the "Age" column
def clean_age(age_str):
    if isinstance(age_str, str):
        age_str = re.findall(r'\d+', age_str)  # Remove non-numeric characters
        if age_str:
            return int(age_str[0])  # Convert the cleaned string to an integer
    return None

# Apply the function to the "Age" column
df['Born[3]'] = df['Born[3]'].apply(clean_age)
df1['Age'] = df1['Age'].apply(clean_age)
# rem

# Save the cleaned DataFrame to a new CSV file
df.to_csv('usa_data/house.csv', index=False)
df1.to_csv('usa_data/senators.csv', index=False)

# %%
senators= pd.read_csv('usa_data/senators.csv')
representatives = pd.read_csv('usa_data/house.csv')
representatives = representatives[representatives["Member"] != "Vacant"]

# %%
def clean_name(name):
    name = name.replace('"', '')
    return unidecode(name)

# %%
house_names = representatives['Member'].tolist()
senators_names = senators['Senator'].tolist()

# %%
import os
def get_page_content(pol_name):
    params = {
        "action": "query",
        "prop": "extracts",
        "exlimit":"1",
        "explaintext": "1",
        "format": "json",
        "titles": pol_name  
    }
    baseurl = "https://en.wikipedia.org/w/api.php?"
    # requests version
    wikitext = requests.get(baseurl, params=params)
    wikijson = wikitext.json()

    # get page id
    pageid = list(wikijson['query']['pages'].keys())[0]
    #wikitext = wikijson['query']['pages'][pageid]['revisions'][0]['*']
    wikitext = wikijson['query']['pages'][pageid]['extract']
    # use regex to count words in wikitext

    return wikitext

if not os.path.isdir('usa_data/senate'):
    os.mkdir('usa_data/senate')

if not os.path.isdir('usa_data/house'):
    os.mkdir('usa_data/house')

# %%
import re
import requests
import string
from unidecode import unidecode

for name in senators_names:
    wikitext = get_page_content(name)
    name = re.sub(r'[".?"]','',name)
    name = clean_name(name)
    with open('usa_data/senate/{}.txt'.format(name), 'w') as f:
        f.write(wikitext)


for name in house_names:
    wikitext = get_page_content(name)
    name = re.sub(r'[".?"]','',name)
    name = clean_name(name)
    with open('usa_data/house/{}.txt'.format(name), 'w') as f:
        f.write(wikitext)

# %%
def getLinks(rapper_name):
    params = {
    "action": "query",
    "prop": "revisions",
    "rvprop": "content",
    "format": "json",
    "titles": rapper_name
    
    }
    baseurl = "https://en.wikipedia.org/w/api.php?"
    # requests version
    wikitext = requests.get(baseurl, params=params)
    wikijson = wikitext.json()


    pageid = list(wikijson['query']['pages'].keys())[0]
    wikitext = wikijson['query']['pages'][pageid]['revisions'][0]['*']
    links = re.findall(r'\[\[(.*?)\]\]', wikitext)
    links = [link.split('|')[0] for link in links]
    links = [link for link in links if link in senators_names or link in house_names]
    print(links)
    # keep only unique links
    links = list(set(links))
    return links

# %%
house_links = dict()
senate_links = dict()
counter = 0

def getPairs(dict1,Names):
    for pol in Names:
        links = getLinks(pol)
        links = [clean_name(link) for link in links]
        dict1[clean_name(pol)] = []
        dict1[clean_name(pol)] += links

getPairs(house_links,house_names)
getPairs(senate_links,senators_names)
# Out:
# ['Kat Cammack', 'Andrew Clyde']
# []
# []
# ['Katie Britt', 'Kevin McCarthy', 'Steve Scalise', 'Earl Blumenauer']
# ['Kevin McCarthy', 'Emilia Sykes']
# []
# ['Kirsten Gillibrand', 'Nancy Pelosi']
# ['Jared Golden', 'Marie Gluesenkamp Perez', 'Jim Costa', 'Lisa Murkowski', 'Lisa Murkowski', 'Sharice Davids', 'Markwayne Mullin', 'Tom Cole', 'Jared Golden', 'Jim Costa', 'Jared Golden', 'Marie Gluesenkamp Perez', 'Brad Finstad']
# ['Martin Heinrich', 'Andy Biggs', 'Paul Gosar', 'Juan Ciscomani']
# ['Kevin McCarthy', 'Joyce Beatty', 'Jasmine Crockett']
# ['Eric Swalwell', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Raúl Grijalva', 'Tom Emmer', 'Garret Graves']
# ['Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Paul Gosar', 'Paul Gosar', 'Abigail Spanberger', 'Pete Stauber']
# ['Ken Buck', 'Paul Gosar', 'Matt Gaetz', 'Paul Gosar', 'Kevin McCarthy', 'Paul Gosar', 'Jim Jordan', 'Kevin McCarthy', 'Ken Buck', 'Jack Bergman', 'Lisa Blunt Rochester']
# ['Kevin McCarthy', 'David Schweikert', 'Lori Chavez-DeRemer']
# ['Bruce Westerman', 'Bruce Westerman', 'Barbara Lee', 'Pramila Jayapal', 'Mark Pocan', 'Pramila Jayapal', 'Barbara Lee', 'Bernie Sanders', 'Ruben Gallego', 'Ruben Gallego', 'Bruce Westerman', 'Barbara Lee', 'Mark Pocan', 'Pramila Jayapal', 'Mario Díaz-Balart']
# ['Nancy Pelosi', 'Michael Cloud']
# ['Alexandria Ocasio-Cortez', 'Ron Johnson', 'Alexandria Ocasio-Cortez', 'Nancy Pelosi', 'Kevin McCarthy', 'Mitch McConnell', 'Andy Biggs', 'Ted Cruz', 'Matt Gaetz', 'Debbie Lesko', 'Kevin McCarthy', 'Ro Khanna', 'Rand Paul', 'Jim Banks', 'Greg Stanton', 'Greg Stanton', 'Chuck Fleischmann', 'Morgan Griffith']
# []
# []
# ['John Boozman', 'John Boozman', 'John Boozman', 'Frederica Wilson', 'Mark Amodei']
# ['Raúl Grijalva', 'Raúl Grijalva', 'Tom Cotton', 'Tom Cotton', 'Kevin McCarthy', 'Pete Stauber', 'Tom Cotton', 'Raúl Grijalva', 'Bonnie Watson Coleman', 'Trent Kelly']
# ['Nancy Pelosi', 'Nancy Pelosi', 'Paul Gosar', 'Alexandria Ocasio-Cortez', 'Jim Banks', 'Grace Meng']
# ['Kyrsten Sinema', 'Jamie Raskin', 'Dan Kildee', 'Jared Huffman', 'Jared Huffman', 'Hakeem Jeffries']
# []
# []
# ['John Garamendi', 'Nancy Pelosi', 'Ami Bera', 'Ayanna Pressley', 'Mitt Romney', 'Nancy Pelosi', 'John Garamendi', 'Blaine Luetkemeyer', 'Chellie Pingree']
# ['Raja Krishnamoorthi', 'Pramila Jayapal', 'Ro Khanna', 'Doris Matsui', 'Doris Matsui', 'Joyce Beatty', 'Julia Brownley']
# ['Rosa DeLauro', 'Alex Padilla', 'Ami Bera', 'Ami Bera', 'Debbie Wasserman Schultz', 'Gus Bilirakis']
# ['Tom McClintock', 'Mark DeSaulnier', 'Martin Heinrich', 'Mark DeSaulnier', 'Jay Obernolte', 'Judy Chu', 'Tim Walberg']
# ['Josh Hawley', 'Alex Padilla', 'Mark DeSaulnier', 'Jahana Hayes']
# ['John Garamendi', 'Nancy Pelosi', 'Josh Harder', 'Buddy Carter', 'Debbie Dingell']
# ['Kevin McCarthy', 'Steny Hoyer', 'Hakeem Jeffries', 'Steny Hoyer', 'Steny Hoyer', 'Marcy Kaptur', 'Steny Hoyer', 'Steny Hoyer', 'Seth Moulton', 'Chuck Schumer', 'Joyce Beatty', 'Bernie Sanders', 'Jerry Nadler', 'Mitch McConnell', 'Adam Schiff', 'Mitt Romney', 'Mitch McConnell', 'Mark Warner', 'Ilhan Omar', 'Tim Kaine', 'Barbara Lee', 'Mark DeSaulnier', 'Steny Hoyer', 'Kevin McCarthy', 'Kevin McCarthy', 'Marcy Kaptur', 'Frank Pallone']
# ['Emanuel Cleaver', 'Raúl Grijalva', 'Hakeem Jeffries', 'Nancy Pelosi', 'Rosa DeLauro', 'Eric Swalwell', 'Katie Porter', 'Adam Schiff', 'Laphonza Butler', 'Emanuel Cleaver', 'Nancy Pelosi', 'Raúl Grijalva', 'Gregory Meeks', 'John B. Larson']
# []
# ['Darrell Issa', 'Nancy Pelosi', 'Rosa DeLauro', 'Barbara Lee', 'Adam Schiff', 'Kevin McCarthy', 'Adam Schiff', 'Kevin McCarthy', 'Ruben Gallego', 'Kevin Mullin', 'Mark Takano']
# ['Eric Swalwell', 'Jared Moskowitz', 'Wiley Nickel']
# ['Steny Hoyer', 'Nancy Pelosi', 'Frank Pallone', 'Nancy Pelosi', 'Frank Pallone', 'Ed Markey', 'Jan Schakowsky', 'Cory Booker', 'Zoe Lofgren', 'Jim Costa', 'Jim Clyburn']
# ['Joe Manchin', 'Alexandria Ocasio-Cortez', 'Nancy Pelosi', 'Chuck Schumer', 'Todd Young', 'Kevin McCarthy', 'Bernie Sanders', 'Hakeem Jeffries', 'John Sarbanes', 'Elizabeth Warren', 'Bernie Sanders', 'Thomas Massie', 'Mark Pocan', 'Rand Paul', 'Pramila Jayapal', 'Nancy Pelosi', 'Zoe Lofgren', 'Anna Eshoo', 'Eric Swalwell', 'Bernie Sanders', 'Raja Krishnamoorthi']
# ['Bryan Steil', 'Ro Khanna', 'Anna Eshoo', 'Pramila Jayapal', 'Jim Costa', 'Jimmy Panetta', 'Anna Eshoo', 'Bryan Steil', 'Amy Klobuchar', 'Sheila Jackson Lee', 'Earl Blumenauer']
# ['Alex Padilla', 'Kevin McCarthy', 'Zoe Lofgren', 'Brian Mast', 'Jamie Raskin']
# ['Nancy Pelosi', 'Patrick McHenry', 'Steve Scalise', 'Hakeem Jeffries', 'Steny Hoyer', 'Jim Clyburn', 'Matt Gaetz', 'Pete Sessions', 'Cathy McMorris Rodgers', 'Jim Jordan', 'Marjorie Taylor Greene', 'Nancy Pelosi', 'Nancy Pelosi', 'Maxine Waters', 'Chuck Schumer', 'Nancy Pelosi', 'Jim Jordan', 'Andy Biggs', 'Andy Biggs', 'Hakeem Jeffries', 'Chuck Schumer', 'Chuck Schumer', 'Mitch McConnell', 'Patrick McHenry', 'Nancy Pelosi', 'Angie Craig', 'Matt Gaetz', 'Tom Cole', 'Andy Biggs', 'Ken Buck', 'Tim Burchett', 'Eli Crane', 'Bob Good', 'Nancy Mace', 'Matt Rosendale', 'Cathy McMorris Rodgers', 'Jay Obernolte', 'Jimmy Panetta', 'Jim Clyburn', 'Steve Scalise', 'Steny Hoyer', 'Nancy Pelosi', 'Hakeem Jeffries', 'Nancy Pelosi', 'Patrick McHenry', 'Doug Lamborn', 'John Sarbanes']
# ['Jared Golden', 'Ed Case', 'Marie Gluesenkamp Perez', 'Mary Peltola', 'Alex Padilla', 'Zoe Lofgren', 'Anna Eshoo', 'David Valadao', 'Henry Cuellar', 'Ed Case', 'Jared Golden', 'Mary Peltola', 'Emanuel Cleaver']
# ['Dan Newhouse', 'Jim Costa', 'Debbie Stabenow', 'Kevin McCarthy', 'Dan Newhouse', 'Alex Padilla', 'Jim Costa', 'Brad Schneider', 'Jodey Arrington']
# ['Alex Padilla', 'Marjorie Taylor Greene', 'Paul Gosar', 'Alexandria Ocasio-Cortez', 'John Garamendi', 'Kevin McCarthy', 'Troy Nehls', 'Burgess Owens']
# ['Alex Padilla', 'Lisa Blunt Rochester', 'Lou Correa']
# []
# ['Ami Bera', 'Tony Cárdenas']
# []
# ['Grace Napolitano', 'Brad Sherman', 'Adam Schiff', 'John Garamendi']
# ['Adam Schiff', 'Adam Schiff', 'Adam Schiff', 'Julia Brownley', 'Matt Cartwright']
# ['Mike Turner', 'Dutch Ruppersberger', 'Kevin McCarthy', 'Laphonza Butler', 'Nancy Pelosi', 'Ilhan Omar', 'Nancy Pelosi', 'Katie Porter', 'Barbara Lee', 'Adam Schiff', 'Adam Schiff', 'Adam Schiff', 'Brad Sherman', 'Tony Cárdenas', 'Judy Chu', 'Brad Sherman', 'Betty McCollum', 'Stephen F. Lynch']
# ['Linda Sánchez', 'Judy Chu', 'Brad Sherman', 'Pete Aguilar', 'John B. Larson', 'Jan Schakowsky']
# ['Steny Hoyer', 'Ken Calvert', 'Darrell Issa', 'Lindsey Graham', 'Sheila Jackson Lee', 'Adam Schiff', 'Judy Chu', 'Adam Schiff', 'Grace Napolitano', 'Bill Pascrell']
# ['Hakeem Jeffries', 'Nancy Pelosi', 'Katherine Clark', 'Ted Lieu', 'Katherine Clark', 'Robin Kelly', 'Grace Napolitano', 'Ted Lieu', 'Katherine Clark', 'Ted Lieu', 'Hakeem Jeffries', 'Ed Case', 'Rick W. Allen']
# ['Marjorie Taylor Greene', 'Lauren Boebert', 'Alex Padilla', 'Jimmy Gomez', 'Jimmy Gomez', 'Ron Estes', 'Ralph Norman']
# ['Elise Stefanik', 'Bonnie Watson Coleman']
# ['Hakeem Jeffries', 'Pete Aguilar', 'Matt Cartwright', 'Debbie Dingell', 'Joe Neguse', 'Nancy Pelosi', 'Hakeem Jeffries', 'Joe Neguse', 'Nancy Pelosi', 'Grace Meng', 'Ro Khanna', 'Rand Paul', 'Marco Rubio', 'Pete Aguilar', 'Pete Aguilar', 'Barry Loudermilk']
# ['Thomas Kean Jr.']
# ['Nancy Pelosi', 'Katherine Clark', 'Nancy Pelosi', 'John B. Larson', 'Nancy Pelosi', 'Grace Napolitano', 'Katherine Clark', 'Dutch Ruppersberger']
# ['Mike Bost', 'Mike Bost', 'Ken Calvert', 'Bill Cassidy', 'Bernie Sanders', 'Ken Calvert', 'Young Kim', 'Mike Bost', 'Eric Swalwell', 'Juan Vargas']
# ['Michelle Steel', 'Marilyn Strickland', 'David Valadao', 'Kevin McCarthy', 'Michelle Steel', 'Marilyn Strickland', 'Marjorie Taylor Greene', 'Grace Meng', 'Mark Takano', 'Sara Jacobs', 'Jake LaTurner']
# ['Mark Takano', 'Mark Takano', 'Sanford Bishop', 'Jim Clyburn']
# []
# ['Patrick McHenry', 'Patrick McHenry', 'Patrick McHenry', 'Jim Clyburn', 'Nancy Pelosi', 'Nancy Pelosi', 'Kevin McCarthy', 'Nancy Pelosi', 'Jim Clyburn', 'Patrick McHenry', 'Rosa DeLauro', 'Jerry Nadler']
# ['Eric Swalwell', 'Ruben Gallego', 'Joaquin Castro', 'Lois Frankel', 'Jim Banks', 'Jack Bergman']
# ['Steve Scalise', 'Young Kim', 'Marilyn Strickland', 'David Valadao', 'Kevin McCarthy', 'Young Kim', 'Ken Calvert', 'Darrell Issa', 'Katie Porter', 'Victoria Spartz', 'Marilyn Strickland']
# ['Henry Cuellar', 'Salud Carbajal', 'Neal Dunn']
# ['Chuck Grassley', 'Elizabeth Warren', 'Alex Padilla', 'Elizabeth Warren', 'Michelle Steel', 'Dean Phillips', 'Ayanna Pressley']
# ['Mike Levin', 'Mike Levin', 'Mike Levin', 'Tom McClintock', 'Mike Levin', 'Michelle Steel', 'Mike Turner', 'Emanuel Cleaver']
# ['Darrell Issa', 'Darrell Issa', 'Darrell Issa', 'Susie Lee', 'Lucy McBath']
# []
# ['Mike Levin', 'Mazie Hirono', 'Ron Wyden', 'Nancy Pelosi', 'Juan Vargas', 'Ronny Jackson', 'Young Kim']
# ['Sara Jacobs', 'Mark Takano', 'Marc Veasey']
# ['Jim Clyburn', 'Nancy Pelosi', 'Danny K. Davis', 'Kay Granger']
# ['Nancy Pelosi', 'Hakeem Jeffries', 'John Hickenlooper', 'John Hickenlooper', 'Alexandria Ocasio-Cortez']
# ['Alexandria Ocasio-Cortez', 'Nancy Pelosi', 'Kevin McCarthy', 'Nancy Pelosi', 'Kevin McCarthy', 'Jim Banks', 'Ilhan Omar', 'Marjorie Taylor Greene', 'Marjorie Taylor Greene', 'Stephanie Bice', 'Jamaal Bowman']
# ['Michael Bennet', 'Kevin McCarthy', 'Michael Bennet', 'Kevin McCarthy', 'Steve Scalise', 'Jim Jordan', 'Hank Johnson', 'Brendan Boyle', 'Buddy Carter']
# ['Jim Jordan', 'Kevin McCarthy']
# ['Susan Wild', 'Dan Crenshaw', 'Sharice Davids']
# ['Andy Ogles', 'Delia Ramirez']
# ['Eric Burlison', 'Greg Casar']
# ['Nancy Pelosi', 'Jim Clyburn', 'Steny Hoyer', 'Jim Clyburn', 'Bob Menendez', 'Steny Hoyer', 'Jim Clyburn', 'Barbara Lee', 'Grace Napolitano']
# []
# ['Kay Granger', 'Kay Granger', 'Nancy Pelosi', 'Steny Hoyer', 'Steny Hoyer', 'Marcy Kaptur', 'Debbie Wasserman Schultz', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Rosa DeLauro', 'Kay Granger', 'Steny Hoyer', 'Maxine Waters']
# ['Mike Turner', 'Derek Kilmer', 'Derek Kilmer', 'Brett Guthrie', 'Blaine Luetkemeyer']
# ['Chris Murphy', 'Chris Murphy', 'Ayanna Pressley', 'Marjorie Taylor Greene', 'Josh Harder', 'Chrissy Houlahan']
# ['Tom Carper', 'Marjorie Taylor Greene', 'Tom Carper', 'Andy Biggs', 'Salud Carbajal']
# ['Kevin McCarthy', 'Rick Scott', 'Nancy Pelosi', 'Kevin McCarthy', 'Marjorie Taylor Greene', 'Nancy Pelosi', 'Kevin McCarthy', 'Jim Jordan', 'Steve Scalise', 'Bennie Thompson', 'Lindsey Graham', 'Jim Jordan', 'Adam Schiff', 'Kevin McCarthy', 'Andy Biggs', 'Ted Lieu', 'Lance Gooden', 'Kevin McCarthy']
# ['Lou Correa', 'Adriano Espaillat']
# ['Kevin Hern', 'Kevin McCarthy', 'Kevin McCarthy', 'Madeleine Dean', 'Cori Bush', 'Jerry Carl']
# ['Becca Balint', 'Josh Brecheen']
# []
# ['Michael Waltz', 'Jeff Van Drew', 'Jennifer Wexton']
# ['Marjorie Taylor Greene', 'Marc Molinaro']
# ['Jim Banks', 'Chellie Pingree']
# ['Rick Scott', 'Linda Sánchez', 'Nancy Pelosi', 'Darren Soto', 'Darren Soto', 'Darren Soto', 'Darren Soto', 'Lloyd Smucker', 'Ron Estes']
# ['Bernie Sanders', 'Bernie Sanders', 'Elizabeth Warren', 'Jared Moskowitz', 'Kevin McCarthy', 'Valerie Foushee']
# []
# ['Nancy Pelosi', 'Doris Matsui', 'Vern Buchanan']
# ['Matt Gaetz', 'Elise Stefanik', 'Marjorie Taylor Greene', 'Kevin McCarthy', 'Jim Jordan', 'Byron Donalds', 'Marjorie Taylor Greene', 'Adam Schiff', 'Matt Gaetz', 'Summer Lee', 'Morgan Luttrell']
# ['Rick Scott', 'Vern Buchanan', 'Yvette Clarke']
# ['Rick Scott', 'Mike Lawler', 'Summer Lee']
# ['Mitt Romney', 'Ed Markey', 'John Cornyn', 'Gus Bilirakis', 'Kathy Castor']
# ['Vern Buchanan', 'Marjorie Taylor Greene', 'Bryan Steil', 'Haley Stevens']
# []
# ['Kevin McCarthy', 'Chip Roy', 'Kevin McCarthy', 'Jim Jordan', 'Lauren Boebert', 'Dan Bishop', 'Andy Biggs', 'Matt Rosendale', 'Anna Paulina Luna', 'Andrew Clyde', 'Pat Fallon']
# ['Alexandria Ocasio-Cortez', 'Rashida Tlaib']
# ['Lois Frankel', 'David Kustoff', 'Jimmy Panetta']
# ['Matt Gaetz', 'Brian Mast', 'Joaquin Castro']
# ['Rick Scott', 'Debbie Wasserman Schultz', 'Nathaniel Moran', 'Kevin Mullin']
# ['Mario Díaz-Balart', 'Ilhan Omar', 'Steve Womack']
# ['Dan Kildee', 'Hakeem Jeffries', 'Eric Swalwell', 'Barbara Lee', 'Tim Kaine', 'Tim Kaine', 'Bernie Sanders', 'Nancy Pelosi', 'Nancy Pelosi', 'Mario Díaz-Balart', 'Bernie Sanders', 'Tim Kaine', 'Bernie Sanders', 'Jared Moskowitz', 'Mario Díaz-Balart', 'Gwen Moore', 'Doris Matsui']
# ['Frederica Wilson', 'Nancy Pelosi', 'Bill Pascrell', 'Marjorie Taylor Greene', 'Tony Gonzales', 'Debbie Wasserman Schultz', 'Tom Cole', 'Raúl Grijalva']
# ['Marjorie Taylor Greene', 'Ilhan Omar', 'Marco Rubio', 'Victoria Spartz']
# []
# ['Lisa Murkowski', 'Nancy Pelosi', 'Ken Buck', 'Mark DeSaulnier']
# ['Jerry Nadler', 'Ken Calvert']
# []
# ['Mazie Hirono', 'Jim Jordan']
# ['Beth Van Duyne', 'Julia Letlow']
# ['Lucy McBath', 'Lucy McBath', 'Seth Magaziner', 'Morgan McGarvey']
# ['Jon Ossoff', 'Lucy McBath', 'Lucy McBath', 'Rich McCormick', 'Mike Levin', 'Dan Meuser']
# []
# ['Eric Swalwell', 'Jerry Carl', 'Byron Donalds']
# []
# ['Mikie Sherrill', 'Ted Lieu', 'John Moolenaar']
# []
# []
# ['Lauren Boebert', 'Alexandria Ocasio-Cortez', 'Ilhan Omar', 'Rashida Tlaib', 'Nancy Pelosi', 'Jim Jordan', 'Andy Biggs', 'Matt Gaetz', 'Jason Crow', 'Jimmy Gomez', 'Jake Auchincloss', 'Lauren Boebert', 'Nikema Williams', 'Sara Jacobs', 'Elise Stefanik', 'Bonnie Watson Coleman', 'Pramila Jayapal', 'Brad Schneider', 'Marsha Blackburn', 'Tom Emmer', 'Paul Gosar', 'Kevin McCarthy', 'Mitch McConnell', 'Mitt Romney', 'Maxine Waters', 'Steve Scalise', 'Jahana Hayes', 'Jimmy Gomez', 'Debbie Wasserman Schultz', 'Steny Hoyer', 'Mitch McConnell', 'Mitt Romney', 'Kevin Cramer', 'Marco Rubio', 'Raphael Warnock', 'Jon Ossoff', 'Bob Good', 'Diana Harshbarger']
# ['Mazie Hirono', 'Mazie Hirono', 'Mazie Hirono', 'Brad Sherman', 'Mazie Hirono', 'Jim Costa', 'Donald Norcross', 'Pete Aguilar']
# ['Hakeem Jeffries', 'Shri Thanedar', 'Derrick Van Orden']
# ['Ted Cruz', 'Russ Fulcher', 'Ted Cruz', 'Lizzie Fletcher', 'Jesús "Chuy" García']
# ['Mike Crapo', 'Mike Crapo', 'Mike Crapo', 'Mitt Romney', 'Nancy Pelosi', 'Mike Crapo', 'Jan Schakowsky']
# []
# ['Danny K. Davis', 'Jan Schakowsky', 'Robin Kelly', 'Robin Kelly']
# ['Alexandria Ocasio-Cortez', 'Cori Bush', 'Jamaal Bowman', 'André Carson', 'Summer Lee', 'Ilhan Omar', 'Ayanna Pressley', 'Rashida Tlaib', 'August Pfluger', 'Alexandria Ocasio-Cortez', 'Jamaal Bowman', 'Cori Bush', 'Summer Lee', 'Ilhan Omar', 'Rashida Tlaib', 'Thomas Massie', 'Delia Ramirez', 'Brittany Pettersen', 'Andrea Salinas']
# []
# ['Pramila Jayapal', 'Debbie Dingell', 'Paul Tonko', 'Judy Chu']
# ['Ayanna Pressley', 'Sean Casten', 'Sean Casten', 'Tim Burchett', 'Ben Cline']
# []
# ['Tammy Duckworth', 'Tammy Duckworth', 'Adriano Espaillat', 'Jan Schakowsky', 'Tammy Duckworth', 'Raja Krishnamoorthi', 'Raja Krishnamoorthi', 'Tammy Duckworth', 'Ro Khanna', 'David Kustoff']
# ['Nancy Pelosi', 'Hakeem Jeffries', 'Cynthia Lummis', 'Grace Napolitano', 'Mike Simpson']
# ['Adriano Espaillat', 'David Valadao']
# []
# ['Mark Takano', 'Mark Takano', 'Steve Scalise', 'Mike Bost', 'Mark Takano', 'Don Beyer', 'Brendan Boyle']
# ['Josh Brecheen', 'Eric Burlison']
# ['Cory Booker', 'Veronica Escobar', 'Dean Phillips', 'Lauren Underwood', 'David Trone', 'Jeff Van Drew']
# []
# ['Trent Kelly', 'Warren Davidson']
# []
# ['Blake Moore', 'Troy Nehls']
# ['Ryan Zinke']
# ['Kevin Hern', 'Mike Braun', 'Ilhan Omar', 'Nancy Pelosi', 'Kevin McCarthy', 'Jim Jordan', 'Tom Emmer', 'Marjorie Taylor Greene', 'Jim Banks', 'Jim Banks', 'Jim Banks', 'Jim Banks', 'Kevin Hern', 'Don Bacon', 'Nanette Barragán']
# []
# ['Kevin McCarthy', 'Mike Braun', 'Kevin McCarthy', 'Jim Jordan', 'Thomas Massie', 'Elissa Slotkin', 'Ben Cardin', 'Steve Daines', 'Tim Walberg', 'Lindsey Graham', 'Pramila Jayapal', 'Michelle Steel']
# ['Nancy Pelosi', 'Greg Pence', 'Greg Pence', 'Dean Phillips']
# ['Alexandria Ocasio-Cortez', 'Cori Bush', 'Jamaal Bowman', 'Summer Lee', 'Ilhan Omar', 'Ayanna Pressley', 'Delia Ramirez', 'Rashida Tlaib', 'August Pfluger', 'Alexandria Ocasio-Cortez', 'Jamaal Bowman', 'Cori Bush', 'Summer Lee', 'Ilhan Omar', 'Delia Ramirez', 'Rashida Tlaib', 'Thomas Massie', 'Steny Hoyer', 'Nancy Pelosi', 'Rob Wittman', 'Steve Scalise']
# ['Kweisi Mfume']
# ['Harriet Hageman', 'Val Hoyle']
# ['Nancy Pelosi', 'Michelle Fischbach', 'Ashley Hinson', 'Ashley Hinson', 'Ashley Hinson']
# ['Mariannette Miller-Meeks', 'Mariannette Miller-Meeks', 'Mariannette Miller-Meeks', 'Mariannette Miller-Meeks', 'Diana Harshbarger', 'Ronny Jackson']
# ['Chuck Grassley', 'Tom Cotton', 'Nancy Pelosi', 'Wiley Nickel', 'Andy Ogles']
# ['Pat Fallon', 'Michelle Fischbach']
# ['Jerry Moran', 'Nicole Malliotakis', 'Kathy Manning']
# ['Ron Estes', 'Henry Cuellar', 'Ron Estes', 'Alexandria Ocasio-Cortez', 'Jake LaTurner', 'Ron Estes', 'Ron Estes', 'Young Kim', 'Teresa Leger Fernandez']
# ['Bernie Sanders', 'Markwayne Mullin', 'Jason Crow', 'Madeleine Dean']
# ['Jake LaTurner', 'Marco Rubio', 'Ted Cruz', 'Jake LaTurner', 'Darren Soto', 'Jimmy Gomez']
# []
# ['Mitch McConnell', 'Virginia Foxx', 'Gerry Connolly', 'Jim Himes']
# ['Rich McCormick', 'Rob Menendez']
# ['Rand Paul', 'Rand Paul', 'Bernie Sanders', 'Ro Khanna', 'Rand Paul', 'Dean Phillips', 'Paul Gosar', 'Chip Roy', 'Stephen F. Lynch', 'Marjorie Taylor Greene', 'Marjorie Taylor Greene', 'Ralph Norman', 'Nancy Pelosi', 'Suzan DelBene', 'Donald Payne Jr.']
# ['Joyce Beatty', 'Katherine Clark']
# []
# ['Kevin McCarthy', 'Steny Hoyer', 'Katherine Clark', 'Kevin McCarthy', 'Jim Clyburn', 'Jim Jordan', 'Jim Jordan', 'Kevin McCarthy', 'Brad Wenstrup', 'Rand Paul', 'Bernie Sanders', 'Kevin McCarthy', 'Jim Jordan', 'Kevin McCarthy', 'Jim Clyburn', 'Steny Hoyer', 'Katherine Clark', 'Steny Hoyer', 'Jim Jordan', 'André Carson', 'Gerry Connolly']
# []
# ['Kevin McCarthy', 'Josh Gottheimer', 'Pramila Jayapal']
# []
# ['Julia Letlow', 'Nikema Williams']
# ['Bill Cassidy', 'Darin LaHood', 'Bill Cassidy', 'Kevin McCarthy', 'Bill Cassidy', 'Ruben Gallego', 'Glenn Grothman']
# ['Susan Collins', 'Susan Collins', 'Jan Schakowsky', 'Jared Golden', 'Brad Schneider', 'Alexandria Ocasio-Cortez', 'Susan Collins', 'Tom McClintock', 'Bill Posey']
# ['Marie Gluesenkamp Perez', 'Mary Peltola', 'Ed Case', 'Angus King', 'Chellie Pingree', 'Susan Collins', 'Nancy Pelosi', 'Michael Bennet', 'Marie Gluesenkamp Perez', 'Jim Costa', 'Marie Gluesenkamp Perez', 'Marie Gluesenkamp Perez', 'Mary Peltola', 'Sylvia Garcia', 'Lance Gooden']
# []
# ['Adam Schiff', 'Ro Khanna', 'Linda Sánchez']
# ['Ben Cardin', 'Ben Cardin', 'Ben Cardin', 'Kevin McCarthy']
# ['Wesley Hunt']
# ['Nancy Pelosi', 'Jim Clyburn', 'Kevin McCarthy', 'Steve Scalise', 'Steve Scalise', 'Nancy Pelosi', 'Nancy Pelosi', 'Marjorie Taylor Greene', 'Ilhan Omar', 'Alexandria Ocasio-Cortez', 'Rashida Tlaib', 'Nancy Pelosi', 'Nancy Pelosi', 'Jim Clyburn', 'Chris Van Hollen', 'John B. Larson', 'Nancy Pelosi', 'Steve Scalise', 'Kevin McCarthy', 'Marcy Kaptur']
# ['Chris Van Hollen', 'Ben Cardin', 'Chris Van Hollen', 'Jamie Raskin', 'Ben Cardin', 'Marjorie Taylor Greene', 'Jamie Raskin', 'Lori Trahan', 'Lauren Underwood']
# ['Ben Cardin', 'Ben Cardin', 'Larry Bucshon']
# ['Chris Van Hollen', 'Chris Van Hollen', 'Bernie Sanders', 'Jared Huffman', 'Dan Kildee', 'Ted Lieu', 'David Trone', 'Joe Manchin', 'Nancy Pelosi', 'Chris Van Hollen', 'Jimmy Panetta']
# ['Chuck Grassley', 'Chuck Grassley', 'Ron Wyden', 'Frank Pallone', 'Rosa DeLauro']
# []
# ['Lori Trahan', 'Elizabeth Warren', 'Katie Porter', 'Rashida Tlaib', 'David Trone']
# ['Ed Markey', 'Jim Jordan', 'Adam Schiff', 'Claudia Tenney', 'Cliff Bentz']
# ['Hakeem Jeffries', 'Steve Scalise', 'Nancy Pelosi', 'Ben Ray Luján', 'Jim Clyburn', 'Nancy Pelosi', 'Linda Sánchez', 'Pete Aguilar', 'Ed Markey', 'Ed Markey', 'Ed Markey', 'Ed Markey', 'Linda Sánchez', 'Ben Ray Luján', 'Steny Hoyer', 'Jim Clyburn', 'Annie Kuster', 'Grace Meng', 'Lois Frankel', 'Julia Brownley', 'Ed Markey', 'Linda Sánchez', 'Pete Aguilar', 'Ben Ray Luján', 'Steve Scalise', 'Alma Adams']
# ['Elizabeth Warren', 'Debbie Wasserman Schultz', 'Nancy Pelosi', 'Don Bacon', 'Elise Stefanik', 'Jacky Rosen', 'Alex Mooney', 'Dan Newhouse']
# ['Elizabeth Warren', 'Ed Markey', 'Elizabeth Warren', 'Maxine Waters', 'Alexandria Ocasio-Cortez', 'Jahana Hayes', 'Ilhan Omar', 'Rashida Tlaib', 'Alexandria Ocasio-Cortez', 'Cori Bush', 'Ilhan Omar', 'Cori Bush', 'Cory Booker', 'Barbara Lee', 'Brad Schneider', 'Ilhan Omar', 'Alexandria Ocasio-Cortez', 'Cori Bush', 'Jamaal Bowman', 'André Carson', 'Summer Lee', 'Ilhan Omar', 'Delia Ramirez', 'Rashida Tlaib', 'August Pfluger', 'Bernie Sanders', 'Ed Markey', 'Ayanna Pressley', 'Katie Porter', 'Guy Reschenthaler']
# []
# []
# ['Steve Scalise', 'Nanette Barragán', 'Andy Biggs']
# ['Bill Huizenga', 'Bill Huizenga', 'Barry Loudermilk', 'Alex Mooney']
# ['Andrea Salinas', 'Keith Self']
# ['Nancy Pelosi', 'John Moolenaar', 'John Moolenaar']
# ['Chris Van Hollen', 'Elissa Slotkin', 'Dan Kildee', 'John Garamendi']
# ['Matt Cartwright', 'Ted Lieu', 'Joe Neguse', 'Nancy Pelosi', 'Hakeem Jeffries', 'Gary Peters', 'Brad Schneider', 'Rashida Tlaib', 'Mark DeSaulnier', 'Tom Emmer']
# ['Debbie Stabenow', 'Mikie Sherrill', 'Debbie Stabenow', 'Debbie Stabenow', 'Rashida Tlaib', 'Ed Markey', 'Dan Kildee', 'Tim Walberg', 'Mikie Sherrill', 'Abigail Spanberger']
# ['Debbie Wasserman Schultz', 'Hakeem Jeffries', 'Eric Swalwell', 'Barbara Lee', 'Steny Hoyer', 'Sara Jacobs', 'Jared Huffman', 'Jamie Raskin', 'Ayanna Pressley', 'Tim Walberg', 'Elissa Slotkin', 'Derek Kilmer']
# ['Kevin McCarthy', 'Elissa Slotkin', 'John Moolenaar', 'Kathy Manning']
# []
# ['Elissa Slotkin', 'Colin Allred', 'Greg Steube']
# ['Ilhan Omar', 'Alexandria Ocasio-Cortez', 'Ilhan Omar', 'Marco Rubio', 'Jim Risch', 'Alexandria Ocasio-Cortez', 'Cori Bush', 'Jamaal Bowman', 'André Carson', 'Summer Lee', 'Ilhan Omar', 'Ayanna Pressley', 'Delia Ramirez', 'August Pfluger', 'Ilhan Omar', 'Jerry Nadler', 'Marjorie Taylor Greene', 'Rich McCormick', 'Ilhan Omar', 'Ken Buck', 'Cori Bush', 'Ilhan Omar', 'Alexandria Ocasio-Cortez', 'Cori Bush', 'Shri Thanedar', 'Debbie Dingell', 'Lori Trahan']
# ['Rashida Tlaib', 'Rashida Tlaib', 'Rashida Tlaib', 'Emilia Sykes', 'Jill Tokuda']
# ['Nancy Pelosi', 'Mary Peltola']
# ['Kevin McCarthy', 'Ben Cline', 'Dan Crenshaw']
# ['Greg Pence', 'Katie Porter']
# ['Brad Schneider', 'August Pfluger', 'Rick Larsen', 'Adam Schiff']
# ['Rashida Tlaib', 'Rashida Tlaib', 'Ayanna Pressley', 'Rashida Tlaib', 'Alexandria Ocasio-Cortez', 'Bernie Sanders', 'Tina Smith', 'Bernie Sanders', 'Kevin McCarthy', 'Nancy Pelosi', 'Steny Hoyer', 'Jim Clyburn', 'Elizabeth Warren', 'Bernie Sanders', 'Cory Booker', 'Kirsten Gillibrand', 'Kevin McCarthy', 'August Pfluger', 'Rashida Tlaib', 'Ro Khanna', 'Rand Paul', 'Ro Khanna', 'Nancy Pelosi', 'Lauren Boebert', 'Alexandria Ocasio-Cortez']
# ['Kevin McCarthy', 'Jim Clyburn', 'Steve Scalise', 'Jim Jordan', 'Jim Banks', 'Kevin McCarthy', 'Ryan Zinke', 'Pete Stauber', 'Nancy Pelosi', 'Nancy Pelosi', 'Jim Clyburn', 'Debbie Dingell', 'Ruben Gallego']
# ['Tina Smith', 'Tina Smith', 'Tina Smith', 'Mariannette Miller-Meeks', 'Tina Smith', 'Randy Feenstra']
# ['Greg Stanton', 'Bryan Steil']
# ['Steve Scalise', 'Bruce Westerman', 'Darin LaHood']
# ['Michael McCaul', 'Ron Wyden', 'Nancy Pelosi', 'Kevin McCarthy', 'Mitch McConnell', 'Nancy Pelosi', 'Mitch McConnell', 'Michael McCaul', 'Nydia Velázquez']
# []
# ['Chuck Edwards', 'Valerie Foushee']
# ['Alexandria Ocasio-Cortez', 'Bernie Sanders', 'Jamaal Bowman', 'Rashida Tlaib', 'Ayanna Pressley', 'Kevin McCarthy', 'Nancy Pelosi', 'Marjorie Taylor Greene', 'Alexandria Ocasio-Cortez', 'Jamaal Bowman', 'Summer Lee', 'Ilhan Omar', 'Ayanna Pressley', 'Delia Ramirez', 'Rashida Tlaib', 'August Pfluger', 'Jamaal Bowman', 'Kat Cammack']
# ['Marc Veasey', 'Randy Weber']
# ['Jim Himes', 'Tom McClintock']
# []
# ['Barbara Lee', 'Maxine Waters', 'Barbara Lee', 'Darrell Issa', 'Jim Costa']
# ['Rick Larsen', 'Nydia Velázquez', 'Nydia Velázquez', 'Nydia Velázquez', 'Nydia Velázquez', 'Rick Larsen', 'Pete Sessions', 'Rick Larsen']
# ['Nikki Budzinski', 'Yadira Caraveo']
# []
# ['Steve Daines', 'Nancy Pelosi', 'Mitt Romney', 'Steve Daines', 'Jon Tester', 'Steve Daines', 'Maria Cantwell', 'Steve Daines', 'Rudy Yakym']
# ['Steve Daines', 'Ryan Zinke', 'Ted Cruz', 'Rand Paul', 'Kevin McCarthy', 'Steve Scalise', 'Jim Jordan', 'Matt Gaetz', 'Kevin McCarthy', 'Jon Tester', 'August Pfluger']
# []
# ['Kevin McCarthy', 'Steve Scalise', 'Jim Jordan', 'Salud Carbajal', 'Seth Moulton', 'Rand Paul', 'Elizabeth Warren', 'Jodey Arrington', 'Jim Banks']
# []
# ['Steven Horsford', 'Donald Payne Jr.']
# ['Steve Womack', 'Suzanne Bonamici']
# ['Jacky Rosen', 'Jacky Rosen', 'Steven Horsford', 'Jacky Rosen', 'Mike Levin']
# ['Joyce Beatty', 'Joyce Beatty', 'Susan Wild', 'Colin Allred']
# []
# ['Suzan DelBene', 'Jeanne Shaheen', 'Peter Welch', 'Katherine Clark', 'Suzan DelBene', 'Derek Kilmer', 'Doug LaMalfa']
# ['Cory Booker', 'Bob Good', 'Alma Adams', 'Ed Case']
# ['Nancy Pelosi', 'Marjorie Taylor Greene', 'Lauren Underwood', 'Michael Waltz']
# []
# []
# ['Cory Booker', 'Nancy Pelosi', 'Bernie Sanders', 'Ayanna Pressley', 'Nancy Pelosi', 'Hakeem Jeffries', 'Alexandria Ocasio-Cortez', 'Bob Menendez', 'Mikie Sherrill', 'Abigail Spanberger', 'Hakeem Jeffries', 'Kevin McCarthy', 'Ilhan Omar', 'Pramila Jayapal', 'Rashida Tlaib', 'Cori Bush', 'Claudia Tenney', 'Brad Schneider', 'Don Bacon', 'Jared Moskowitz', 'André Carson', 'Joe Manchin', 'Clay Higgins']
# ['Cathy McMorris Rodgers', 'Cathy McMorris Rodgers', 'Anna Eshoo', 'Steny Hoyer', 'Nancy Pelosi', 'Bob Menendez', 'Cory Booker', 'Cathy McMorris Rodgers', 'Nancy Pelosi', 'Richard Neal']
# ['Bob Menendez', 'Kevin McCarthy', 'Kevin McCarthy', 'Josh Gottheimer', 'Mikie Sherrill', 'Bob Menendez', 'Sydney Kamlager-Dove', 'Jen Kiggans']
# ['Bob Menendez', 'Bob Menendez', 'Bob Menendez', 'Cory Booker', 'Morgan McGarvey']
# ['Nancy Pelosi', 'Brad Sherman']
# ['Nancy Pelosi', 'Thomas Massie', 'Dina Titus']
# ['Elissa Slotkin', 'Chrissy Houlahan', 'Nancy Pelosi', 'Jason Crow', 'Elissa Slotkin', 'Abigail Spanberger', 'Kim Schrier', 'Elissa Slotkin']
# ['Robin Kelly', 'Yvette Clarke', 'Brad Schneider', 'Norma Torres', 'Bruce Westerman']
# ['Maria Cantwell', 'Jake Ellzey']
# ['Martin Heinrich', 'Derrick Van Orden']
# ['Ben Ray Luján', 'Ben Ray Luján', 'Elizabeth Warren', 'Alexandria Ocasio-Cortez', 'Ben Ray Luján', 'Jake LaTurner', 'Nancy Mace']
# ['Josh Gottheimer', 'Greg Landsman']
# []
# ['Kevin McCarthy', 'Jasmine Crockett']
# ['Michael McCaul', 'Michael McCaul', 'Joaquin Castro', 'Dutch Ruppersberger', 'Nancy Pelosi', 'Grace Meng', 'Michael McCaul', 'Barbara Lee']
# ['Tammy Duckworth', 'Gregory Meeks', 'Doug LaMalfa']
# ['Blaine Luetkemeyer', 'Sam Graves', 'Sam Graves', 'Jerry Nadler', 'Sam Graves', 'Bennie Thompson']
# ['Katherine Clark', 'Kevin McCarthy', 'Nancy Pelosi', 'Nancy Pelosi', 'Pete Aguilar', 'Nancy Pelosi', 'Matt Cartwright', 'Debbie Dingell', 'Ted Lieu', 'Nancy Pelosi', 'Barbara Lee', 'David Trone', 'Kevin McCarthy', 'Gregory Meeks', 'Debbie Wasserman Schultz', 'Yvette Clarke', 'Nanette Barragán', 'Josh Gottheimer', 'Steven Horsford', 'Lizzie Fletcher', 'Joe Neguse', 'Dean Phillips', 'Sara Jacobs', 'Jerry Nadler', 'Pete Aguilar', 'Kevin McCarthy', 'Jared Huffman']
# ['Ron Wyden', 'Cory Booker', 'Ritchie Torres', 'Kathy Castor']
# ['Jerry Nadler', 'Maxine Waters', 'Ritchie Torres', 'Nancy Pelosi', 'Jerry Nadler', 'Marie Gluesenkamp Perez', 'Harriet Hageman']
# ['Marco Rubio', 'Nancy Pelosi', 'Marjorie Taylor Greene', 'Alexandria Ocasio-Cortez', 'Victoria Spartz', 'Nancy Mace', 'Tracey Mann']
# ['Jim Jordan', 'Jim Jordan', 'Lance Gooden', 'Hakeem Jeffries', 'Jim Jordan', 'Maxine Waters', 'Sanford Bishop']
# ['Brad Schneider', 'Rashida Tlaib', 'Ilhan Omar', 'Neal Dunn']
# ['Rashida Tlaib', 'Chuck Schumer', 'Kirsten Gillibrand', 'Ro Khanna', 'Bernie Sanders', 'Bernie Sanders', 'Elizabeth Warren', 'Cori Bush', 'Ilhan Omar', 'Nancy Pelosi', 'Ilhan Omar', 'Ayanna Pressley', 'Rashida Tlaib', 'Cori Bush', 'Jamaal Bowman', 'Ed Markey', 'Elizabeth Warren', 'Bernie Sanders', 'Cory Booker', 'Nancy Pelosi', 'Kyrsten Sinema', 'Angus King', 'Paul Gosar', 'Nancy Pelosi', 'Jamaal Bowman', 'Katie Porter', 'Ro Khanna', 'Brad Schneider', 'Jamaal Bowman', 'Cori Bush', 'Summer Lee', 'Ilhan Omar', 'Ayanna Pressley', 'Delia Ramirez', 'Rashida Tlaib', 'August Pfluger', 'Kevin McCarthy', 'Nydia Velázquez', 'Bob Menendez', 'Pramila Jayapal', 'Bernie Sanders', 'Cori Bush', 'Elise Stefanik', 'Joe Neguse', 'Ilhan Omar']
# ['Marilyn Strickland', 'Beth Van Duyne']
# ['Bernie Sanders', 'Elizabeth Warren', 'Cori Bush', 'Nancy Pelosi', 'Chuck Schumer', 'Kevin McCarthy', 'August Pfluger', 'Thomas Massie', 'Lauren Boebert', 'Cori Bush']
# ['Mike Lawler', 'Kevin McCarthy', 'Josh Gottheimer', 'Adam Schiff', 'Claudia Tenney', 'Mike Lawler', 'Mike Lawler', 'Nick Langworthy', 'Laurel Lee']
# []
# ['Cory Mills', 'Nathaniel Moran']
# []
# ['Kevin McCarthy', 'Blake Moore', 'Nancy Pelosi', 'Henry Cuellar', 'Jake LaTurner', 'Mitt Romney', 'Steve Scalise', 'Chip Roy', 'Byron Donalds', 'Jim Banks', 'Ilhan Omar', 'Adam Schiff', 'Markwayne Mullin', 'Marjorie Taylor Greene', 'Seth Moulton', 'Jacky Rosen', 'Nancy Pelosi', 'Nick Langworthy', 'Alexandria Ocasio-Cortez', 'David Rouzer', 'Norma Torres']
# []
# ['Greg Landsman', 'Mike Lawler']
# ['Nancy Pelosi', 'Jim Banks', 'Tom Tiffany', 'Jake Auchincloss']
# ['Joseph Morelle', 'Kevin Hern', 'Mary Gay Scanlon']
# ['Kirsten Gillibrand', 'Michael McCaul']
# []
# []
# []
# ['Mike Ezell', 'Maxwell Frost']
# ['Debbie Wasserman Schultz', 'Henry Cuellar']
# ['Ted Budd', 'Ted Budd', 'Kathy Manning', 'Tracey Mann', 'Lisa McClain']
# ['Mitt Romney', 'Thom Tillis', 'Elise Stefanik']
# ['Jennifer Wexton']
# []
# ['Maxine Waters', 'Kevin McCarthy', 'Elizabeth Warren', 'Nancy Pelosi', 'Steny Hoyer', 'Mike Lawler', 'Maxine Waters', 'Maxine Waters', 'Kevin McCarthy', 'Michael McCaul', 'Cathy McMorris Rodgers']
# ['Thom Tillis', 'Chuck Edwards', 'Chuck Edwards', 'Mike Ezell']
# ['Katherine Clark', 'Donald Norcross']
# ['Ted Budd', 'Ted Budd', 'Kevin Mullin', 'Zach Nunn']
# []
# ['Kevin Cramer', 'Kevin Cramer', 'Kevin Cramer', 'Colin Allred']
# ['Nick LaLota', 'Nick Langworthy']
# ['Ken Calvert', 'Randy Weber']
# ['Steven Horsford', 'Mike Turner', 'Alexandria Ocasio-Cortez', 'Mike Turner', 'Steven Horsford', 'Ami Bera']
# ['Jerry Nadler', 'Jerry Nadler', 'Kevin McCarthy', 'Steve Scalise', 'Kevin McCarthy', 'Warren Davidson', 'Kevin McCarthy', 'Matt Gaetz', 'Chip Roy', 'Byron Donalds', 'Kevin Hern', 'Steve Scalise', 'Adam Schiff', 'Bennie Thompson', 'Lindsey Graham', 'Nancy Pelosi', 'Bill Pascrell', 'Ken Buck', 'Matt Gaetz', 'Jerry Nadler', 'Steve Scalise', 'Hank Johnson', 'Doug Lamborn']
# ['Rob Wittman']
# []
# []
# ['Jim Jordan', 'Andy Biggs', 'Mike Braun', 'Jim Jordan', 'Pramila Jayapal', 'Matt Gaetz', 'Jerry Nadler', 'Adam Schiff', 'Zoe Lofgren', 'Ron Wyden', 'Steve Daines', 'Nancy Pelosi', 'Darin LaHood']
# ['Bernie Sanders', 'Steny Hoyer', 'Nancy Pelosi']
# ['Adam Schiff', 'Jim Himes', 'Darrell Issa', 'Joyce Beatty', 'Jim Himes', 'Adam Schiff', 'Darrell Issa']
# ['Jake Ellzey']
# ['Michael Cloud', 'Kevin Hern']
# ['Hakeem Jeffries', 'Dale Strong', 'Shri Thanedar']
# []
# []
# ['Jim Banks', 'Kevin McCarthy', 'Steve Scalise', 'Jim Jordan', 'Lauren Boebert', 'Josh Brecheen', 'Kevin McCarthy', 'Bob Good', 'Bob Good', 'Kevin McCarthy', 'Steve Scalise', 'Tom Emmer', 'Jim Banks', 'Troy Balderson', 'Joseph Morelle']
# ['Markwayne Mullin', 'Markwayne Mullin', 'Jim Banks', 'Jim Jordan', 'Byron Donalds', 'Kevin Hern', 'Lauren Boebert', 'Kevin McCarthy', 'Markwayne Mullin', 'Aaron Bean', 'Nikki Budzinski']
# []
# ['Pete Sessions', 'Markwayne Mullin', 'Josh Brecheen', 'Sharice Davids', 'Mary Peltola', 'Pete Sessions', 'Mario Díaz-Balart']
# ['Cliff Bentz', 'Lauren Boebert']
# ['Mark Amodei', 'Suzan DelBene']
# ['Jake Auchincloss', 'Stephanie Bice']
# ['Ron Wyden', 'Ron Wyden', 'Ron Wyden', 'Brad Schneider', 'Ron Wyden', 'Zoe Lofgren', 'Robert Aderholt']
# ['Erin Houchin', 'Wesley Hunt']
# ['Greg Casar', 'Juan Ciscomani']
# ['Delia Ramirez', 'Hillary Scholten']
# []
# ['Marc Veasey', 'Elizabeth Warren', 'Colin Allred', 'Mike Bost', 'Ken Buck']
# []
# ['Brendan Boyle', 'Mary Gay Scanlon', 'Chrissy Houlahan', 'Susan Wild', 'Kat Cammack', 'Sharice Davids', 'Veronica Escobar']
# ['Madeleine Dean', 'Chrissy Houlahan', 'Susan Wild', 'Susan Wild', 'Joseph Morelle', 'Susan Wild']
# ['Mary Gay Scanlon', 'Madeleine Dean', 'Susan Wild', 'Mikie Sherrill', 'Jahana Hayes', 'Dusty Johnson']
# ['Marjorie Taylor Greene', 'Nancy Pelosi', 'Mary Gay Scanlon', 'Steven Horsford']
# ['Debbie Dingell', 'Ted Lieu', 'Joe Neguse', 'Hakeem Jeffries', 'Jared Golden', 'Marjorie Taylor Greene', 'Tony Cárdenas']
# ['Jim Banks', 'Lucy McBath']
# []
# ['Mitt Romney', 'Darren Soto']
# ['Bernie Sanders', 'Bernie Sanders', 'Alexandria Ocasio-Cortez', 'Cori Bush', 'Jamaal Bowman', 'André Carson', 'Ilhan Omar', 'Ayanna Pressley', 'Delia Ramirez', 'Rashida Tlaib', 'August Pfluger', 'Alexandria Ocasio-Cortez', 'Jamaal Bowman', 'Cori Bush', 'Ilhan Omar', 'Delia Ramirez', 'Rashida Tlaib', 'Thomas Massie', 'Laurel Lee', 'Anna Paulina Luna']
# []
# ['Kevin McCarthy', 'Ayanna Pressley']
# []
# []
# ['Bernie Sanders', 'Nick LaLota', 'Monica De La Cruz']
# ['Sheldon Whitehouse', 'Gabe Amo', 'Jennifer McClellan', 'Celeste Maloy']
# ['Morgan Luttrell', 'Rich McCormick']
# ['Lindsey Graham', 'Lauren Boebert', 'Ilhan Omar', 'Kevin McCarthy', 'Jim Clyburn', 'Teresa Leger Fernandez', 'Nicole Malliotakis']
# []
# []
# []
# ['Nancy Pelosi', 'Paul Gosar', 'Jimmy Gomez']
# ['Hakeem Jeffries', 'Katherine Clark', 'Nancy Pelosi', 'Chris Van Hollen', 'Ben Ray Luján', 'Nancy Pelosi', 'Steve Scalise', 'Tom Emmer', 'Nancy Pelosi', 'Kevin McCarthy', 'Bob Menendez', 'John B. Larson', 'Nancy Pelosi', 'Steny Hoyer', 'Bob Menendez', 'Nancy Pelosi', 'Steny Hoyer', 'Chris Van Hollen', 'Henry Cuellar', 'Maxine Waters', 'Kevin McCarthy', 'Steve Scalise', 'Tom Emmer', 'Bob Menendez', 'John B. Larson', 'Chris Van Hollen', 'Ben Ray Luján', 'Katherine Clark', 'Ken Calvert', 'Anna Eshoo']
# []
# ['Mike Rounds', 'Chrissy Houlahan']
# ['Marsha Blackburn', 'Marjorie Taylor Greene', 'Marjorie Taylor Greene', 'Ashley Hinson']
# ['Matt Gaetz', 'Kevin McCarthy', 'Sean Casten']
# ['Nancy Pelosi', 'Bill Pascrell', 'Paul Gosar']
# []
# ['Kevin McCarthy', 'Marsha Blackburn', 'Ted Cruz', 'Chip Roy', 'Kevin McCarthy', 'Zach Nunn', 'Brittany Pettersen']
# []
# []
# ['Marsha Blackburn', 'Marsha Blackburn', 'Raja Krishnamoorthi', 'Brian Mast']
# []
# ['Marc Molinaro', 'Jared Moskowitz']
# ['Pete Sessions', 'Pete Sessions', 'Ted Cruz', 'Bernie Sanders', 'Tom Cotton', 'John Cornyn', 'Ted Cruz', 'Josh Hawley', 'Tammy Duckworth', 'Tom Cotton', 'Angie Craig', 'Jason Crow']
# ['Michael C. Burgess', 'Jim Jordan', 'Byron Donalds', 'Kevin McCarthy', 'Michael C. Burgess', 'Keith Self', 'Hillary Scholten']
# ['Byron Donalds', 'Randy Feenstra']
# ['Nancy Pelosi', 'Bill Pascrell', 'Marjorie Taylor Greene', 'Jared Golden', 'Mark E. Green']
# ['Jake Ellzey', 'Melanie Stansbury', 'Shontel Brown']
# ['Wesley Hunt', 'Wesley Hunt', 'Lizzie Fletcher', 'Veronica Escobar', 'Russ Fulcher']
# ['Dan Crenshaw', 'Kevin McCarthy', 'Ted Cruz', 'Marjorie Taylor Greene', 'Kevin McCarthy', 'Joaquin Castro', 'Troy Nehls', 'Anna Paulina Luna', 'Seth Magaziner']
# []
# ['Gregory Meeks', 'Gregory Meeks', 'Bennie Thompson', 'Lloyd Doggett', 'Lloyd Doggett', 'Bennie Thompson', 'Gregory Meeks', 'Brian Higgins', 'Patrick McHenry']
# ['Burgess Owens', 'Matt Rosendale']
# ['Rosa DeLauro', 'Rosa DeLauro', 'Cathy McMorris Rodgers', 'Mitt Romney', 'Rosa DeLauro', 'Cathy McMorris Rodgers', 'Diana DeGette']
# ['Jon Tester', 'Katie Porter', 'Ashley Hinson', 'Sara Jacobs']
# ['Mitt Romney', 'Nancy Pelosi', 'Ann Wagner', 'Brad Wenstrup']
# ['Kevin McCarthy', 'Chris Deluzio']
# ['Sylvia Garcia', 'Veronica Escobar', 'Veronica Escobar', 'Veronica Escobar', 'Madeleine Dean', 'Lizzie Fletcher']
# ['Colin Allred', 'Tom Cole', 'Colin Allred', 'Ted Cruz', 'Colin Allred', 'Kevin McCarthy', 'Bill Pascrell', 'Sanford Bishop', 'Colin Allred', 'Tom Cole', 'Sam Graves']
# ['Lloyd Doggett', 'Sylvia Garcia', 'Lloyd Doggett', 'Zoe Lofgren']
# ['David Valadao', 'Don Bacon']
# ['Lloyd Doggett', 'Ted Cruz', 'John Cornyn', 'Steny Hoyer', 'Gregory Meeks', 'Brad Sherman', 'Matt Cartwright', 'Lois Frankel']
# ['Ted Cruz', 'John Cornyn', 'Ted Cruz', 'Mitch McConnell', 'Marco Rubio', 'Rand Paul', 'Mike Lee', 'Chuck Schumer', 'Alexandria Ocasio-Cortez', 'Nancy Pelosi', 'Thomas Massie', 'Lance Gooden', 'Michael Cloud', 'Andy Biggs', 'Mike Lee', 'Thomas Massie', 'Kelly Armstrong', 'Ken Buck', 'Nancy Mace', 'Tom McClintock', 'Andy Biggs', 'Paul Gosar', 'Josh Hawley', 'Alexandria Ocasio-Cortez', 'Marjorie Taylor Greene', 'Steve Scalise', 'Kevin McCarthy', 'Elise Stefanik', 'Lance Gooden', 'Ken Buck', 'Thomas Massie', 'Andrew Clyde', 'Thomas Massie', 'Byron Donalds', 'Kevin McCarthy', 'Marjorie Taylor Greene', 'Thomas Massie', 'Lauren Boebert', 'Ralph Norman', 'Beth Van Duyne', 'Matt Gaetz', 'Paul Gosar', 'Grace Meng', 'Alexandria Ocasio-Cortez', 'Kim Schrier']
# ['Kevin McCarthy', 'Frank J. Mrvan', 'Jay Obernolte']
# ['Marco Rubio', 'John Cornyn', 'Ted Cruz', 'Mario Díaz-Balart', 'Mario Díaz-Balart', 'Bob Good']
# ['Jim Banks', 'Ritchie Torres', 'Nikema Williams']
# []
# ['Jim Banks']
# ['Jim Jordan', 'Kevin McCarthy', 'Debbie Lesko', 'Troy Balderson']
# ['Alexandria Ocasio-Cortez', 'Hakeem Jeffries', 'Katherine Clark', 'Pete Aguilar', 'Nancy Pelosi', 'Steny Hoyer', 'Jim Clyburn', 'John Hoeven', 'Nancy Pelosi', 'Jim Costa', 'Lou Correa', 'Virginia Foxx']
# ['Veronica Escobar', 'Sylvia Garcia', 'Jesús "Chuy" García', 'Jared Golden']
# ['Nancy Pelosi', 'Marc Veasey', 'Eli Crane', "Anthony D'Esposito"]
# []
# ['Pete Sessions', 'Pete Sessions', 'Haley Stevens', 'Ted Cruz', 'Pete Sessions', 'Pete Sessions', 'Elizabeth Warren', 'Brendan Boyle', 'Steven Horsford', 'Kelly Armstrong']
# ['Pete Sessions', 'Juan Vargas', 'Ann Wagner']
# []
# ['Lloyd Doggett', 'Bernie Sanders', 'Elizabeth Warren', 'Alexandria Ocasio-Cortez', 'Lloyd Doggett', 'Yadira Caraveo', 'Lori Chavez-DeRemer']
# ['Ted Cruz', 'Jim Banks', 'Rick W. Allen', 'Don Beyer']
# ['Sheila Jackson Lee', 'Joaquin Castro', 'Greg Casar', 'Nancy Pelosi', 'Jan Schakowsky', 'Michael McCaul', 'Greg Casar', 'Sheila Jackson Lee']
# ['Lizzie Fletcher', 'Kevin McCarthy', 'Lizzie Fletcher', 'Val Hoyle', 'Glenn Ivey']
# ['Kevin McCarthy', 'Frank J. Mrvan']
# ['Gabe Amo']
# []
# ['Mike Lee', 'Marjorie Taylor Greene', 'Jay Obernolte', 'August Pfluger']
# ['Peter Welch', 'Peter Welch', 'Bernie Sanders', 'Peter Welch', 'Aaron Bean']
# ['Bob Latta', 'André Carson']
# ['Jen Kiggans', 'Thomas Kean Jr.']
# []
# ['Tim Kaine', 'Mark Warner', 'Tim Kaine', 'Jennifer McClellan', 'Jennifer McClellan', 'Gabe Amo']
# ['Jim Banks', 'Tony Gonzales', 'Marjorie Taylor Greene']
# ['Sean Casten', 'Angie Craig']
# ['Nancy Pelosi', 'Rashida Tlaib', 'Alexandria Ocasio-Cortez', 'Nancy Pelosi', 'Alexandria Ocasio-Cortez', 'Elissa Slotkin', 'Greg Stanton']
# ['Mike Lee', 'Martin Heinrich', 'Martin Heinrich', 'Mark Warner', 'Mark Warner', 'Mike Lee', 'Martin Heinrich', 'Brian Babin', 'Mike Bost']
# ['Nancy Pelosi', 'Paul Gosar']
# ['Nancy Pelosi', 'Ilhan Omar', 'Marjorie Taylor Greene', 'Michael Waltz', 'Dan Bishop']
# ['Darrell Issa', 'Darrell Issa', 'Steve Scalise', 'Brett Guthrie']
# ['Hakeem Jeffries', 'Derek Kilmer', 'Annie Kuster', 'Derek Kilmer', 'Annie Kuster', 'Suzanne Bonamici', 'Thomas Massie']
# ['Sam Graves', 'Sam Graves', 'Betty McCollum']
# ['Jared Golden', 'Mary Peltola', 'Jim Costa', 'Bernie Sanders', 'Jared Golden', 'Jared Golden', 'Jared Golden', 'Mary Peltola']
# ['David Valadao', 'Seth Moulton']
# ['Frank Pallone', 'Frank Pallone', 'Kay Granger', 'Ryan Zinke', 'Sanford Bishop', 'Mitch McConnell', 'Ryan Zinke', 'Frank Pallone', 'Kay Granger', 'Marco Rubio', 'Joni Ernst', 'Patrick McHenry', 'Gwen Moore']
# ['Jim Himes', 'Suzan DelBene', 'Jim Himes', 'Suzan DelBene', 'Dan Kildee']
# ['Mark Pocan', 'Raúl Grijalva', 'Mark Pocan', 'Bernie Sanders', 'Bernie Sanders', 'Jamie Raskin', 'Nancy Pelosi', 'August Pfluger', 'Bernie Sanders', 'Barbara Lee', 'Mark Pocan', 'Jesús "Chuy" García', 'Ro Khanna', 'Raúl Grijalva', 'Mark Pocan', 'Clay Higgins']
# ['Chip Roy', 'Mikie Sherrill']
# []
# ['Young Kim', 'Michelle Steel', 'Michelle Steel', 'Young Kim', 'Michelle Steel', 'Ritchie Torres']
# []
# ['Shelley Moore Capito', 'Joe Manchin', 'Shelley Moore Capito', 'Joe Manchin', 'Matt Gaetz', 'Ted Cruz', 'Josh Hawley', 'Shelley Moore Capito', 'John Moolenaar', 'Seth Moulton']
# ['Zoe Lofgren', 'Zoe Lofgren', 'Amy Klobuchar', 'Pete Stauber', 'Greg Steube']
# ['Pramila Jayapal', 'Tammy Baldwin', 'Tammy Baldwin', 'Tammy Baldwin', 'Tammy Baldwin', 'Pramila Jayapal', 'Barbara Lee', 'Brad Schneider', 'Bernie Sanders', 'Rashida Tlaib', 'Alexandria Ocasio-Cortez', 'Tammy Baldwin', 'Tammy Baldwin', 'Tammy Baldwin', 'Raúl Grijalva', 'Pramila Jayapal']
# ['Mitch McConnell', 'Thom Tillis', 'Chip Roy', 'Jill Tokuda', 'Gabe Vasquez']
# ['Tammy Baldwin', 'Tammy Baldwin', 'Brad Schneider', 'Nancy Pelosi', 'Cathy McMorris Rodgers', 'Debbie Wasserman Schultz']
# []
# ['Garret Graves']
# ['Claudia Tenney']
# []
# ['Ted Cruz', 'Kevin McCarthy', 'Cynthia Lummis', 'Kevin McCarthy', 'Erin Houchin']
# ['Katie Britt', 'Mike Lee', 'Marco Rubio', 'Katie Britt', 'Bill Hagerty', 'Alex Padilla']
# ['Tommy Tuberville', 'Mitch McConnell', 'Rick Scott', 'Robert Aderholt', 'Tommy Tuberville', 'Tom Cotton', 'Tom Cotton', 'Jerry Carl', 'Tommy Tuberville', 'J. D. Vance', 'Eric Schmitt', 'Eric Schmitt', 'Pete Ricketts']
# ['John Barrasso', 'Joe Manchin', 'Maria Cantwell', 'Mitch McConnell', 'John Thune', 'John Barrasso', 'Susan Collins', 'Mitch McConnell', 'Susan Collins', 'Joe Manchin', 'Steve Daines', 'Mitt Romney', 'Susan Collins', 'Joe Manchin', 'Jeanne Shaheen', 'Angus King', 'John Barrasso', 'Maria Cantwell', 'Joe Manchin', 'John Thune', 'John Cornyn', 'Lindsey Graham']
# []
# ['Mark Kelly', 'Greg Stanton', 'Tammy Baldwin', 'Bernie Sanders', 'Angus King', 'David Schweikert', 'Tammy Baldwin', 'Chuck Schumer', 'Mark Kelly', 'Joe Manchin', 'Patty Murray', 'Joe Manchin', 'Nancy Pelosi', 'Susan Collins', 'Lisa Murkowski', 'Bill Cassidy', 'Joe Manchin', 'Bernie Sanders', 'Mark Kelly', 'Joe Manchin', 'Bernie Sanders', 'Roger Wicker', 'Jeff Merkley', 'Greg Stanton', 'Mark Kelly', 'Mitt Romney', 'Mark Kelly', 'Marsha Blackburn', 'Kevin Cramer']
# ['Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Kyrsten Sinema', 'Bill Hagerty', 'Rick Scott', 'Ben Ray Luján']
# ['Tom Cotton', 'Debbie Stabenow', 'Steve Womack', 'Tom Cotton', 'Tom Cotton', 'Steve Womack', 'Tom Cotton', 'Debbie Stabenow', 'Rand Paul', 'Marco Rubio', 'Jerry Moran', 'John Hoeven']
# ['John Boozman', 'Bruce Westerman', 'Jason Crow', 'Joni Ernst', 'Lindsey Graham', 'Marco Rubio', 'Mitt Romney', 'Ted Cruz', 'Mike Lee', 'John Cornyn', 'Ted Cruz', 'Lindsey Graham', 'Dick Durbin', 'Mary Peltola', 'Marco Rubio', 'Catherine Cortez Masto', 'Nancy Pelosi', 'Marco Rubio', 'Ben Cardin', 'Chris Van Hollen', 'Bruce Westerman', 'John Boozman', 'Chris Murphy', 'Josh Hawley', 'Bill Cassidy', 'Gary Peters', 'James Lankford', 'Steve Daines']
# ['Laphonza Butler', 'Tony Cárdenas', 'Jon Ossoff', 'Raphael Warnock', 'Joaquin Castro', 'Laphonza Butler', 'Raphael Warnock', 'John Fetterman', 'Tommy Tuberville', 'Jon Ossoff']
# ['Alex Padilla', 'Jimmy Gomez', 'Barbara Lee', 'Katie Porter', 'Adam Schiff', 'Alex Padilla', 'Pete Ricketts', 'Pete Ricketts']
# ['John Hickenlooper', 'Patty Murray', 'Jon Tester', 'John Hickenlooper', 'Ken Buck', 'John Hickenlooper', 'Kirsten Gillibrand', 'Ken Buck', 'Elizabeth Warren', 'Mitt Romney', 'Bernie Sanders', 'Chris Murphy', 'Mike Lee', 'Chris Coons', 'Elizabeth Warren', 'Ted Cruz', 'Angus King', 'Bernie Sanders', 'Tim Kaine', 'Brian Schatz', 'Tammy Duckworth', 'Ted Cruz', 'John Hickenlooper', 'Kirsten Gillibrand', 'Patty Murray', 'Jon Tester', 'Jim Risch', 'Kirsten Gillibrand', 'Jeff Merkley']
# ['Michael Bennet', 'Michael Bennet', 'Michael Bennet', 'Cynthia Lummis', 'Bill Hagerty']
# ['Chris Murphy', 'Chuck Schumer', 'Amy Klobuchar', 'Hank Johnson', 'Ed Markey', 'Mitch McConnell', 'Lindsey Graham', 'Marco Rubio', 'Ben Cardin', 'Ro Khanna', 'Brian Schatz', 'Bernie Sanders', 'Brian Schatz', 'Tammy Duckworth', 'Tammy Baldwin', 'Ben Cardin', 'Jeff Merkley', 'Jerry Moran', 'Mazie Hirono', 'Chris Murphy', 'Jon Tester', 'Joe Manchin', 'Rand Paul', 'Rand Paul', 'Mike Lee']
# ['Richard Blumenthal', 'Steny Hoyer', 'Bernie Sanders', 'John Cornyn', 'Patty Murray', 'Bernie Sanders', 'Mike Lee', 'Richard Blumenthal', 'Brian Schatz', 'Tom Cotton', 'Brian Schatz', 'Elizabeth Warren', 'Tammy Baldwin', 'Mazie Hirono']
# ['Chris Coons', 'John Barrasso', 'Shelley Moore Capito', 'Ron Johnson', 'Lisa Blunt Rochester', 'Susan Collins', 'Joe Manchin', 'Mitt Romney', 'Rick Scott', 'Susan Collins', 'Bernie Sanders', 'Chris Coons', 'Ron Johnson', 'Susan Collins', 'John Barrasso', 'Mike Crapo', 'Debbie Stabenow']
# ['James Lankford', 'Tom Carper', 'Tom Carper', 'Joe Manchin', 'Cory Booker', 'Lindsey Graham', 'Thom Tillis', 'Josh Hawley', 'Ted Cruz', 'Marco Rubio', 'Tammy Duckworth', 'Bernie Sanders', 'Tom Carper', 'James Lankford', 'Kirsten Gillibrand', 'Joe Manchin', 'Joe Manchin', 'Jerry Moran']
# ['Rick Scott', 'Mark Warner', 'Mark Warner', 'Jim Risch', 'Ben Cardin', 'Bob Menendez', 'Nancy Pelosi', 'Mitt Romney', 'Chris Coons', 'Rand Paul', 'Mike Lee', 'Rick Scott', 'Ted Cruz', 'Roger Wicker', 'Ted Cruz', 'Rand Paul', 'Ted Cruz', 'Rand Paul', 'Cathy McMorris Rodgers', 'Rick Scott', 'Jim Risch', 'Ben Cardin', 'Mark Warner', 'Mark Warner', 'John Boozman', 'Ron Johnson', 'John Hoeven']
# ['Marco Rubio', 'Mitch McConnell', 'Todd Young', 'Steve Daines', 'Marco Rubio', 'Steve Daines', 'Ron Wyden', 'Mitch McConnell', 'Todd Young', 'Mitch McConnell', 'Mike Braun', 'Josh Hawley', 'Ted Cruz', 'Ron Johnson', 'Lindsey Graham', 'Mitch McConnell', 'John Cornyn', 'Ron Johnson', 'Mike Braun', 'Tommy Tuberville', 'Todd Young', 'Steve Daines', 'Marco Rubio', 'Josh Hawley', 'Jacky Rosen', 'Mark Kelly']
# ['Raphael Warnock', 'Raphael Warnock', 'Hank Johnson', 'Hank Johnson', 'Bernie Sanders', 'Nancy Pelosi', 'Lucy McBath', 'Raphael Warnock', 'Raphael Warnock', 'Raphael Warnock', 'Josh Hawley', 'Ben Ray Luján', 'Raphael Warnock', 'Alex Padilla']
# ['Jon Ossoff', 'Jon Ossoff', 'Chuck Schumer', 'Cory Booker', 'Sherrod Brown', 'Kirsten Gillibrand', 'Jeff Merkley', 'Chris Murphy', 'Bernie Sanders', 'Brian Schatz', 'Elizabeth Warren', 'Tommy Tuberville', 'Ted Cruz', 'Marco Rubio', 'Elizabeth Warren', 'Cindy Hyde-Smith', 'Jon Ossoff', 'Jon Ossoff', 'Alex Padilla', 'Peter Welch']
# ['Mazie Hirono', 'John Hoeven', 'Chuck Schumer', 'Tammy Baldwin', 'Ed Case', 'Mazie Hirono', 'Mazie Hirono', 'Bernie Sanders', 'Martin Heinrich', 'Sheldon Whitehouse', 'Bernie Sanders', 'Todd Young', 'Jeff Merkley', 'Mazie Hirono', 'John Hoeven', 'Mike Lee', 'Chris Murphy', 'Mike Lee', 'Chris Murphy', 'Tim Scott']
# ['Brian Schatz', 'Ed Case', 'Hank Johnson', 'Tammy Duckworth', 'Brian Schatz', 'Ed Case', 'Ed Case', 'Ted Cruz', 'Josh Hawley', 'Elizabeth Warren', 'Nikema Williams', 'Ed Case', 'Ed Case', 'Brian Schatz', 'Martin Heinrich', 'Ed Markey', 'Chris Murphy', 'Martin Heinrich']
# ['Jim Risch', 'Ron Wyden', 'Sherrod Brown', 'Mike Simpson', 'Jim Risch', 'Mike Simpson', 'Jim Risch', 'Sherrod Brown', 'Ron Wyden', 'Susan Collins', 'Tom Carper', 'Chuck Schumer']
# ['Mike Crapo', 'Bob Menendez', 'Marco Rubio', 'Marco Rubio', 'Mitch McConnell', 'Chris Murphy', 'John Cornyn', 'Ted Cruz', 'Mike Crapo', 'Jeanne Shaheen', 'Marco Rubio', 'Bob Menendez', 'Bob Menendez', 'Jeff Merkley', 'Michael Bennet', 'Mark Warner', 'Jeff Merkley']
# ['Chuck Schumer', 'John Thune', 'Mitch McConnell', 'John Cornyn', 'Lindsey Graham', 'Tammy Duckworth', 'Chuck Schumer', 'Steny Hoyer', 'Chuck Schumer', 'Cory Booker', 'Elizabeth Warren', 'Tammy Duckworth', 'Veronica Escobar', 'Rick Scott', 'Jeff Merkley', 'Bernie Sanders', 'Josh Hawley', 'Tammy Duckworth', 'Mitch McConnell', 'John Cornyn', 'John Cornyn', 'John Thune', 'Chuck Grassley', 'John Thune', 'Mitch McConnell', 'John Thune', 'Ron Wyden']
# ['Dick Durbin', 'Grace Meng', 'Raja Krishnamoorthi', 'Mazie Hirono', 'Raja Krishnamoorthi', 'Mazie Hirono', 'Jared Golden', 'Deb Fischer', 'Kyrsten Sinema', 'Marco Rubio', 'Ben Cardin', 'Raja Krishnamoorthi', 'Raja Krishnamoorthi', 'Dick Durbin', 'Todd Young', 'Catherine Cortez Masto', 'Maggie Hassan']
# ...
# ['Roger Wicker', 'Roger Wicker', 'Chuck Schumer', 'Susan Collins', 'Mitt Romney', 'Roger Wicker', 'Rand Paul', 'Jon Tester', 'Mitch McConnell', 'Chuck Schumer', 'Roger Wicker', 'Tina Smith', 'Marsha Blackburn']
# ['Eric Schmitt', 'Eric Schmitt', 'Eric Schmitt', 'Eric Schmitt', 'Mitch McConnell', 'Chuck Schumer', 'Ted Cruz', 'Bernie Sanders', 'Chuck Schumer', 'Ted Cruz', 'Josh Harder', 'Mitch McConnell', 'Bernie Sanders', 'Adam Schiff', 'Mark Warner', 'Ted Cruz', 'Tom Cotton', 'Eric Schmitt', 'Eric Schmitt', 'Eric Schmitt', 'Tom Cotton', 'Jon Ossoff', 'Mike Braun', 'Rick Scott']
# ['Josh Hawley', 'Josh Hawley', 'Josh Hawley', 'Mitch McConnell', 'Josh Hawley', 'Josh Hawley', 'Josh Hawley', 'Katie Britt', 'Markwayne Mullin', 'J. D. Vance', 'Katie Britt']
# ['Jerry Moran', 'Richard Blumenthal', 'Jerry Moran', 'Michael Bennet', 'Chris Van Hollen', 'Maria Cantwell', 'John Barrasso', 'Steve Daines', 'Matt Rosendale', 'Matt Rosendale', 'Steve Daines', 'Steve Daines', 'Chuck Schumer', 'Elizabeth Warren', 'Rand Paul', 'Ronny Jackson', 'Matt Rosendale', 'Michael Bennet', 'Chris Van Hollen', 'Steve Daines', 'Maria Cantwell', 'John Barrasso', 'John Barrasso', 'Richard Blumenthal', 'Jerry Moran', 'Amy Klobuchar', 'John Barrasso', 'Sheldon Whitehouse']
# ['Mitch McConnell', 'Rick Scott', 'Jon Tester', 'Ryan Zinke', 'Rick Scott', 'Jon Tester', 'Lisa Murkowski', 'Rick Scott', 'Ron Wyden', 'Ryan Zinke', 'Rick Scott', 'Jon Tester', 'Mike Rounds', 'James Lankford', 'Tom Cotton', 'Mike Rounds']
# ['Pete Ricketts', 'Pete Ricketts', 'Pete Ricketts', 'Tammy Baldwin', 'Martin Heinrich', 'Elizabeth Warren', 'Ed Markey']
# ['Deb Fischer', 'Deb Fischer', 'Deb Fischer', 'Deb Fischer', 'Markwayne Mullin', 'Laphonza Butler', 'Katie Britt', 'Laphonza Butler']
# ['Jacky Rosen', 'Chuck Schumer', 'Chris Van Hollen', 'Gary Peters', 'Elizabeth Warren', 'Chris Van Hollen', 'Gary Peters', 'Jacky Rosen', 'Tammy Duckworth', 'Tina Smith']
# ['Catherine Cortez Masto', 'Susie Lee', 'Kyrsten Sinema', 'Susie Lee', 'Catherine Cortez Masto', 'Rick Scott', 'Kevin Cramer', 'Kevin Cramer', 'Mitt Romney']
# ['Maggie Hassan', 'Ben Cardin', 'Ben Cardin', 'Ben Cardin', 'Chuck Schumer', 'Maggie Hassan', 'Jim Risch', 'Susan Collins', 'Mitch McConnell', 'Chuck Schumer', 'Bernie Sanders', 'Maggie Hassan', 'Ben Cardin', 'Ben Cardin', 'Roger Wicker', 'Mark Warner']
# ['Jeanne Shaheen', 'Jeanne Shaheen', 'Jeanne Shaheen', 'Patty Murray', 'Ben Cardin', 'Jeanne Shaheen', 'Tammy Duckworth']
# ['Cory Booker', 'Jim Risch', 'Ben Cardin', 'Ben Cardin', 'Jim Risch', 'Ben Cardin', 'Chuck Schumer', 'Patty Murray', 'Nancy Pelosi', 'Jim Clyburn', 'Nancy Pelosi', 'Jim Clyburn', 'Rob Menendez', 'Thomas Kean Jr.', 'Bernie Sanders', 'Chris Murphy', 'Chuck Schumer', 'Chuck Schumer', 'John Fetterman', 'Rob Menendez', 'Thomas Kean Jr.', 'Jim Clyburn', 'Chuck Schumer', 'Patty Murray', 'Cory Booker', 'Ben Cardin', 'Ben Cardin', 'Jim Risch', 'Jim Risch', 'Ben Cardin', 'Lindsey Graham', 'Bob Casey Jr.', 'John Thune', 'Ben Cardin']
# ['Bob Menendez', 'Ted Cruz', 'Bob Menendez', 'Kirsten Gillibrand', 'Elizabeth Warren', 'Bernie Sanders', 'Chris Coons', 'Lindsey Graham', 'Thom Tillis', 'Chuck Grassley', 'Bob Menendez', 'Bernie Sanders', 'Bob Menendez', 'Mitt Romney', 'Frank Pallone', 'Joe Manchin', 'Joe Manchin', 'Bob Menendez', 'Ed Markey', 'Thom Tillis', 'Shelley Moore Capito']
# ['Don Beyer', 'Don Beyer', 'David Schweikert', 'Ben Ray Luján', 'Jerry Nadler', 'Ben Ray Luján', 'Don Beyer', 'Deb Fischer', 'Mazie Hirono', 'Mazie Hirono', 'Angus King']
# ['Martin Heinrich', 'Nancy Pelosi', 'Jim Clyburn', 'Katherine Clark', 'Teresa Leger Fernandez', 'Teresa Leger Fernandez', 'Jim Clyburn', 'Katherine Clark', 'Martin Heinrich', 'Cynthia Lummis', 'Jon Ossoff', 'Mark Kelly', 'Cynthia Lummis']
# ['Dick Durbin', 'Mitch McConnell', 'Mark Warner', 'Elizabeth Warren', 'Kirsten Gillibrand', 'Mitch McConnell', 'Debbie Stabenow', 'Mark Warner', 'Elizabeth Warren', 'Dick Durbin', 'Jon Ossoff', 'Raphael Warnock', 'Mitch McConnell', 'Kirsten Gillibrand', 'Nancy Pelosi', 'Mitch McConnell', 'Chuck Grassley', 'Josh Hawley', 'Ron Wyden', 'Cory Booker', 'Maxine Waters', 'Nancy Pelosi', 'Steny Hoyer', 'Ron Wyden', 'Lindsey Graham', 'Dick Durbin', 'Lindsey Graham', 'Bob Casey Jr.', 'Joe Manchin', 'Kirsten Gillibrand', 'Richard Blumenthal', 'Mark Warner', 'Bob Menendez', 'Mark Warner', 'Elizabeth Warren', 'Debbie Stabenow', 'Kirsten Gillibrand', 'Amy Klobuchar', 'Mitch McConnell', 'Mitch McConnell', 'Patty Murray', 'Mitch McConnell', 'Susan Collins', 'Mike Crapo']
# ['Chuck Schumer', 'Chuck Schumer', 'Rand Paul', 'Ted Cruz', 'Cory Booker', 'Elizabeth Warren', 'Bernie Sanders', 'Chuck Schumer', 'Michael Bennet', 'Michael Bennet', 'Chris Coons', 'Joe Manchin']
# ['Ted Budd', 'Mitt Romney', 'Ted Budd', 'Cory Booker', 'Tom Cotton', 'Mike Rounds', 'Joni Ernst']
# ['Thom Tillis', 'Wiley Nickel', 'Kathy Manning', 'Mark Kelly', 'Lindsey Graham', 'Wiley Nickel', 'Thom Tillis', 'John Fetterman', 'Peter Welch', 'Markwayne Mullin', 'John Fetterman']
# ['Kevin Cramer', 'John Barrasso', 'Brian Schatz', 'Chuck Grassley', 'John Cornyn', 'Chris Murphy', 'Kevin Cramer', 'John Barrasso', 'Brian Schatz', 'Jerry Moran', 'Mike Lee', 'John Boozman', 'Marco Rubio']
# ['John Hoeven', 'Kelly Armstrong', 'John Hoeven', 'Nancy Pelosi', 'Lindsey Graham', 'Nancy Pelosi', 'Kelly Armstrong', 'John Hoeven', 'Jacky Rosen', 'Mitt Romney', 'Kyrsten Sinema', 'Jacky Rosen']
# ['J. D. Vance', 'Mike Crapo', 'Bernie Sanders', 'Tim Kaine', 'Ben Cardin', 'Marco Rubio', 'Roger Wicker', 'Jeff Merkley', 'Nancy Pelosi', 'Roger Wicker', 'Bob Menendez', 'Mark Warner', 'Chris Coons', 'Elizabeth Warren', 'Elizabeth Warren', 'Bernie Sanders', 'Tammy Duckworth', 'J. D. Vance', 'Mike Crapo', 'Mike Crapo', 'Mike Crapo', 'Bernie Sanders', 'Amy Klobuchar', 'Bob Casey Jr.']
# ['Sherrod Brown', 'Sherrod Brown', 'Sherrod Brown', 'John Fetterman', 'Bob Casey Jr.', 'Josh Hawley', 'Marco Rubio', 'Sherrod Brown', 'Peter Welch', 'Katie Britt', 'John Fetterman', 'Eric Schmitt']
# ['Markwayne Mullin', 'Chris Coons', 'Marco Rubio', 'Markwayne Mullin', 'Chris Coons', 'Steve Daines', 'Bill Cassidy', 'Tom Cotton']
# ['James Lankford', 'Josh Brecheen', 'Sharice Davids', 'Elise Stefanik', 'Troy Nehls', 'Pat Fallon', 'Nancy Pelosi', 'Kevin McCarthy', 'Bernie Sanders', 'Tom Cole', 'Sharice Davids', 'Mary Peltola', 'Josh Brecheen', 'James Lankford', 'Eric Schmitt', 'Pete Ricketts', 'Peter Welch', 'Ted Budd']
# ['Jeff Merkley', 'Chuck Grassley', 'Mike Crapo', 'Earl Blumenauer', 'Jeff Merkley', 'Chuck Schumer', 'Rand Paul', 'Chris Murphy', 'Lindsey Graham', 'Jeff Merkley', 'Lindsey Graham', 'Bernie Sanders', 'Chris Murphy', 'Mike Lee', 'Elizabeth Warren', 'Mike Lee', 'Tim Scott', 'Lindsey Graham', 'Jeff Merkley', 'Frank Pallone', 'Tammy Baldwin', 'Darrell Issa', 'Cory Booker', 'Yvette Clarke', 'Bob Casey Jr.', 'Gary Peters', 'Earl Blumenauer', 'Jeff Merkley', 'Mike Crapo', 'Chuck Grassley', 'Richard Neal', 'Chuck Grassley', 'Patty Murray', 'Dick Durbin']
# ['Ron Wyden', 'Bernie Sanders', 'Ron Wyden', 'Bernie Sanders', 'Mike Lee', 'Rand Paul', 'Dick Durbin', 'Peter Welch', 'Rand Paul', 'Chris Murphy', 'Chris Murphy', 'Mike Lee', 'Tammy Baldwin', 'Brian Schatz', 'Amy Klobuchar', 'Elizabeth Warren', 'Tom Carper', 'Michael Bennet', 'Ron Wyden', 'Lindsey Graham', 'Brian Schatz', 'Ron Wyden', 'Mark Warner', 'Jim Risch', 'Jim Risch', 'Michael Bennet']
# ['John Fetterman', 'Susan Collins', 'Tim Scott', 'Chuck Schumer', 'Patty Murray', 'Marco Rubio', 'Joe Manchin', 'Joe Manchin', 'Brian Schatz', 'John Fetterman', 'Susan Collins', 'Bob Menendez', 'Ben Cardin', 'Sherrod Brown', 'Amy Klobuchar']
# ['Bob Casey Jr.', 'Bernie Sanders', 'Bernie Sanders', 'Chris Coons', 'Tim Kaine', 'Alex Padilla', 'Ted Budd', 'Ted Budd', 'J. D. Vance']
# []
# ['Bernie Sanders', 'John Cornyn', 'John Cornyn', 'Bernie Sanders', 'Ben Cardin', 'Bernie Sanders', 'Amy Klobuchar', 'Jon Tester']
# ['Tim Scott', 'Chuck Grassley', 'Bernie Sanders', 'Chuck Grassley', 'Chuck Grassley', 'Dick Durbin', 'Chuck Grassley', 'Joni Ernst', 'Tom Cotton', 'Joe Manchin', 'Chuck Schumer', 'Richard Blumenthal', 'Rand Paul', 'Bill Cassidy', 'Roger Wicker', 'Tom Cotton', 'John Barrasso', 'Joni Ernst', 'Jeanne Shaheen', 'Cory Booker', 'Chris Coons', 'Thom Tillis', 'John Barrasso', 'Mitt Romney', 'Tim Scott', 'Chuck Grassley', 'Dick Durbin', 'Bernie Sanders', 'Chuck Grassley', 'Chuck Grassley', 'Lisa Murkowski', 'Bob Menendez', 'John Thune']
# ['Bob Casey Jr.', 'Mike Braun', 'Lindsey Graham', 'Cory Booker', 'Cory Booker', 'Nancy Pelosi', 'Dick Durbin', 'Rick Scott', 'Marco Rubio', 'Mitch McConnell', 'Lindsey Graham', 'Joni Ernst', 'Elizabeth Warren', 'Tim Kaine', 'Brian Schatz', 'Tammy Baldwin']
# ['Mitch McConnell', 'Dick Durbin', 'Mitch McConnell', 'John Cornyn', 'Dick Durbin', 'Roger Wicker', 'Mitch McConnell', 'John Barrasso', 'Mitch McConnell', 'John Barrasso', 'Mike Rounds', 'John Cornyn', 'John Cornyn', 'Mitch McConnell', 'Chuck Schumer', 'Angus King', 'Chuck Grassley', 'Bernie Sanders', 'Chris Murphy', 'Mike Lee', 'Roger Wicker', 'Mitch McConnell', 'Lindsey Graham', 'Mitt Romney', 'John Cornyn', 'Lisa Murkowski', 'John Barrasso', 'John Cornyn', 'Mike Rounds', 'Roger Wicker', 'John Cornyn', 'Dick Durbin', 'Dick Durbin', 'Dick Durbin', 'Chuck Grassley', 'Lindsey Graham', 'Bob Menendez']
# ['John Thune', 'John Thune', 'Tim Scott', 'John Thune', 'Shelley Moore Capito', 'Steve Daines', 'Steve Daines', 'Thom Tillis']
# ['Bill Hagerty', 'David Kustoff', 'Mitt Romney', 'Cynthia Lummis', 'Marco Rubio', 'Richard Blumenthal', 'Amy Klobuchar', 'Bill Hagerty', 'Cindy Hyde-Smith', 'Mike Braun', 'Kyrsten Sinema']
# ['Marsha Blackburn', 'Mitt Romney', 'Kevin Cramer', 'Marsha Blackburn', 'Mark Kelly', 'Tommy Tuberville', 'John Hickenlooper']
# ['Ted Cruz', 'Chuck Grassley', 'Sheldon Whitehouse', 'Mitch McConnell', 'Dick Durbin', 'John Thune', 'Jerry Moran', 'Ted Cruz', 'Joaquin Castro', 'Ted Cruz', 'Alexandria Ocasio-Cortez', 'Ted Cruz', 'John Thune', 'Jerry Moran', 'John Thune', 'Ted Cruz', 'Dick Durbin', 'John Thune', 'Chuck Grassley', 'Sheldon Whitehouse', 'Maria Cantwell', 'Lisa Murkowski']
# ['John Cornyn', 'Roger Wicker', 'Mike Lee', 'Rand Paul', 'Mitt Romney', 'Raphael Warnock', 'Lindsey Graham', 'Mitt Romney', 'Mitch McConnell', 'Maria Cantwell', 'Mike Lee', 'Tom Cotton', 'Josh Hawley', 'Matt Gaetz', 'Marjorie Taylor Greene', 'Tom Cotton', 'Ron Johnson', 'Eric Swalwell', 'John Cornyn', 'Bernie Sanders', 'Tim Scott', 'Lindsey Graham', 'Mike Lee', 'John Cornyn', 'Angus King', 'Tammy Baldwin', 'Tim Kaine', 'Elizabeth Warren']
# ['Don Beyer', 'Mitt Romney', 'Ted Cruz', 'Ted Cruz', 'Josh Hawley', 'Chip Roy', 'Rand Paul', 'Kirsten Gillibrand', 'Dick Durbin', 'Tom Cotton', 'Chuck Grassley', 'Amy Klobuchar', 'Bernie Sanders', 'Chris Murphy', 'Bernie Sanders', 'Rand Paul', 'Jerry Moran', 'Lindsey Graham', 'Rand Paul', 'Rand Paul', 'Bernie Sanders', 'Mitt Romney', 'Don Beyer', 'Brian Schatz', 'John Hoeven', 'Brian Schatz', 'Richard Blumenthal']
# ['Mike Lee', 'John Thune', 'Ted Cruz', 'Susan Collins', 'Lisa Murkowski', 'Ted Cruz', 'Rand Paul', 'Susan Collins', 'Lisa Murkowski', 'Ron Johnson', 'Mike Lee', 'Kevin Cramer', 'Kyrsten Sinema', 'Jacky Rosen', 'Mike Braun']
# ['Peter Welch', 'Patty Murray', 'Amy Klobuchar', 'Chuck Schumer', 'Catherine Cortez Masto', 'Sheldon Whitehouse', 'Patty Murray', 'Peter Welch', 'Chuck Schumer', 'Rand Paul', 'Chris Murphy', 'Mike Lee', 'Ro Khanna', 'Dick Durbin', 'Elizabeth Warren', 'Ted Cruz', 'Debbie Wasserman Schultz', 'Ro Khanna', 'Elizabeth Warren', 'Elizabeth Warren', 'Elizabeth Warren', 'Alexandria Ocasio-Cortez', 'Earl Blumenauer', 'John Fetterman', 'Angus King', 'Kyrsten Sinema', 'Peter Welch', 'Amy Klobuchar', 'Peter Welch', 'Lindsey Graham', 'Patty Murray', 'Sheldon Whitehouse', 'Patty Murray', 'Sheldon Whitehouse', 'Sherrod Brown', 'Ben Cardin']
# ['Bernie Sanders', 'Becca Balint', 'Bernie Sanders', 'Bernie Sanders', 'Bernie Sanders', 'Jim Jordan', 'Steny Hoyer', 'Bernie Sanders', 'Becca Balint', 'Bernie Sanders', 'Ted Budd', 'J. D. Vance', 'Raphael Warnock', 'Markwayne Mullin']
# ['Marco Rubio', 'Chuck Schumer', 'Elizabeth Warren', 'Tim Kaine', 'Tim Kaine', 'Tim Kaine', 'Tim Kaine', 'Chuck Schumer', 'Elizabeth Warren', 'Amy Klobuchar', 'Jerry Moran', 'Joe Manchin', 'John Thune', 'Tim Kaine', 'Don Beyer', 'Tim Kaine', 'Chuck Schumer', 'Elizabeth Warren', 'Marco Rubio', 'Jeanne Shaheen', 'Jeff Merkley', 'Jim Risch']
# ['Mark Warner', 'Debbie Wasserman Schultz', 'Mark Warner', 'Mark Warner', 'Mark Warner', 'Elizabeth Warren', 'Rob Wittman', 'Kirsten Gillibrand', 'Mark Warner', 'Marco Rubio', 'Ben Cardin', 'Patty Murray', 'Michael Bennet', 'Bernie Sanders', 'Tammy Duckworth', 'Mark Warner', 'Nancy Pelosi', 'Tim Scott', 'Angus King', 'Angus King', 'Ted Cruz']
# ['Bernie Sanders', 'Chuck Schumer', 'Debbie Stabenow', 'Tammy Baldwin', 'Bernie Sanders', 'Bob Menendez', 'Michael Bennet', 'Maria Cantwell', 'Debbie Stabenow', 'Maria Cantwell', 'Chris Van Hollen', 'Ed Markey', 'Mitch McConnell', 'Debbie Stabenow', 'Tammy Baldwin', 'Bob Menendez', 'Michael Bennet', 'Maria Cantwell', 'Bernie Sanders', 'Bernie Sanders', 'Chuck Schumer', 'Mitch McConnell', 'Ron Wyden']
# ['Roger Wicker', 'Roger Wicker', 'Lisa Murkowski', 'Joe Manchin', 'Jon Tester', 'Patty Murray', 'Patty Murray', 'Debbie Stabenow', 'Patty Murray', 'Ron Wyden', 'Susan Collins', 'Patty Murray', 'Jon Tester', 'Lisa Murkowski', 'Joe Manchin', 'Roger Wicker', 'Debbie Stabenow', 'John Cornyn']
# ['Shelley Moore Capito', 'Lisa Murkowski', 'Maria Cantwell', 'John Barrasso', 'Shelley Moore Capito', 'Bernie Sanders', 'John Hickenlooper', 'Gary Peters', 'Jon Tester', 'Lisa Murkowski', 'Mitch McConnell', 'Jeff Van Drew', 'Bill Hagerty', 'Tom Cotton', 'Ted Cruz', 'John Cornyn', 'John Cornyn', 'Mitch McConnell', 'Mike Lee', 'Mitch McConnell', 'Tom Carper', 'Mitt Romney', 'Rick Scott', 'Lindsey Graham', 'Marco Rubio', 'Susan Collins', 'Marco Rubio', 'Ben Cardin', 'Steve Scalise', 'Bob Casey Jr.', 'Susan Collins', 'Susan Collins', 'Chuck Schumer', 'Chuck Schumer', 'Shelley Moore Capito', 'Bernie Sanders', 'Marsha Blackburn', 'Debbie Stabenow', 'Cory Booker', 'Shelley Moore Capito', 'Maria Cantwell', 'John Barrasso', 'Lisa Murkowski', 'Chris Coons', 'Richard Blumenthal', 'Kirsten Gillibrand', 'Chris Coons']
# ['Joe Manchin', 'Mitch McConnell', 'Joni Ernst', 'Tom Carper', 'Alex Mooney', 'Joe Manchin', 'Mitch McConnell', 'Deb Fischer', 'Susan Collins', 'Lisa Murkowski', 'Lindsey Graham', 'Kirsten Gillibrand', 'Patty Murray', 'Amy Klobuchar', 'Joe Manchin', 'John Cornyn', 'Ted Cruz', 'Susan Collins', 'Lisa Murkowski', 'Joe Manchin', 'Tom Cotton', 'Joni Ernst', 'Susan Collins', 'Alex Mooney', 'Joni Ernst', 'Joe Manchin', 'Joni Ernst', 'Mike Rounds', 'Cory Booker', 'Gary Peters']
# ['Tammy Baldwin', 'Gary Peters', 'Tom Carper', 'Tammy Baldwin', 'Mitt Romney', 'Jim Jordan', 'Tom Tiffany', 'Tammy Baldwin', 'Tom Carper', 'Gary Peters', 'Marco Rubio', 'Jerry Moran', 'Rand Paul']
# ['Chuck Schumer', 'Brian Schatz', 'Patty Murray', 'Ron Johnson', 'Mark Pocan', 'Mark Pocan', 'Ron Johnson', 'Amy Klobuchar', 'Bernie Sanders', 'Cory Booker', 'Mitch McConnell', 'Chuck Schumer', 'Rand Paul', 'Chris Murphy', 'Bernie Sanders', 'Chris Murphy', 'Mike Lee', 'Gary Peters', 'Jerry Moran', 'Mark Pocan', 'Patty Murray', 'Ron Johnson', 'Ted Cruz', 'Deb Fischer', 'Tim Scott', 'Chris Murphy']
# ['Mitch McConnell', 'Joni Ernst', 'Shelley Moore Capito', 'John Thune', 'Joe Manchin', 'Tom Carper', 'Mitch McConnell', 'John Thune', 'Jon Tester', 'John Hoeven', 'Cynthia Lummis', 'Cynthia Lummis', 'Cynthia Lummis', 'Lisa Murkowski', 'John Thune', 'Cynthia Lummis', 'Lisa Murkowski', 'Jon Tester', 'Jon Tester', 'John Hoeven', 'Tom Carper', 'Joe Manchin', 'Jon Tester', 'Roger Wicker']
# ['John Barrasso', 'Mitt Romney', 'Ryan Zinke', 'Debbie Lesko', 'Gwen Moore', 'Mitt Romney', 'Rand Paul', 'John Barrasso', 'Chris Van Hollen', 'John Barrasso', 'Jan Schakowsky', 'John Barrasso', 'John Hickenlooper', 'Ben Ray Luján', 'Ben Ray Luján']

# %%
from unidecode import unidecode

def clean_name(name):
    name = name.replace('"', '')
    return unidecode(name)

house_links_copy = {}
senate_links_copy = {}
#copy congress_dict
# loop through the dictionary and clean the names
for key, value in house_links.items():
    key = clean_name(key)
    house_links_copy[clean_name(key)] = [clean_name(name) for name in value]

for key, value in senate_links.items():
    key = clean_name(key)
    senate_links_copy[clean_name(key)] = [clean_name(name) for name in value]


senate_links = senate_links_copy
house_links = house_links_copy

# %%
# save house names to json
import json

with open('usa_data/house_links.json', 'w') as f:
    json.dump(house_links, f)

with open('usa_data/senate_links.json', 'w') as f:
    json.dump(senate_links, f)

# %%
# create csv with name and house or senate
all_list = []

# delete file if exists
if os.path.exists('usa_data/all_list.csv'):
    os.remove('usa_data/all_list.csv')

for name in house_names:
    with open('usa_data/all_list.csv', 'a') as f:
        f.write(str(name + "," + "house"+ "\n"))
        f.close()


for name in senators_names:
    with open('usa_data/all_list.csv', 'a') as f:
        f.write(str(name + "," + "senate"+ "\n"))
        f.close()
